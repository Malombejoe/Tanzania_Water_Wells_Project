# %% [markdown]
# ## Project Submission
#
# Please fill out:
# * Student name: Joseph Malombe Ndemei

# %% [markdown]
# # 1) Initial Set up

# %% [markdown]
# <b>Import libraries</b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import precision_score, accuracy_score, roc_curve, auc, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
plt.style.use('dark_background')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <b>Import Data</b>

# %%
df_1 = pd.read_csv('Tanzanian_data_set.csv')
df_1.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
# 3          soft          good           dry             dry
# 4          soft          good      seasonal        seasonal
#
#                  source           source_type  source_class  \
# 0                spring                spring   groundwater
# 1  rainwater harvesting  rainwater harvesting       surface
# 2                   dam                   dam       surface
# 3           machine dbh              borehole   groundwater
# 4  rainwater harvesting  rainwater harvesting       surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
# 3  communal standpipe multiple    communal standpipe
# 4           communal standpipe    communal standpipe
#
# [5 rows x 40 columns]

# %%
# Import the training set labels
df_2 = pd.read_csv('Tanzanian_labels.csv')
df_2.drop('id', axis = 1, inplace = True)
df_2.head()
# Out:
#      status_group
# 0      functional
# 1      functional
# 2      functional
# 3  non functional
# 4      functional

# %%
# Join both data sets together, but get rid of the duplicated id column
df = pd.concat([df_1, df_2], axis = 1)
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... water_quality  \
# 0  34.938093  -9.856322                  none            0  ...          soft
# 1  34.698766  -2.147466              Zahanati            0  ...          soft
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...          soft
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...          soft
# 4  31.130847  -1.825359               Shuleni            0  ...          soft
#
#   quality_group      quantity  quantity_group                source  \
# 0          good        enough          enough                spring
# 1          good  insufficient    insufficient  rainwater harvesting
# 2          good        enough          enough                   dam
# 3          good           dry             dry           machine dbh
# 4          good      seasonal        seasonal  rainwater harvesting
#
#             source_type source_class              waterpoint_type  \
# 0                spring  groundwater           communal standpipe
# 1  rainwater harvesting      surface           communal standpipe
# 2                   dam      surface  communal standpipe multiple
# 3              borehole  groundwater  communal standpipe multiple
# 4  rainwater harvesting      surface           communal standpipe
#
#   waterpoint_type_group    status_group
# 0    communal standpipe      functional
# 1    communal standpipe      functional
# 2    communal standpipe      functional
# 3    communal standpipe  non functional
# 4    communal standpipe      functional
#
# [5 rows x 41 columns]

# %% [markdown]
# Inspect the columns

# %%
df.columns
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group', 'status_group'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#         num_private   region_code  district_code    population  \
# count  59400.000000  59400.000000   59400.000000  59400.000000
# mean       0.474141     15.297003       5.629747    179.909983
# std       12.236230     17.587406       9.633649    471.482176
# min        0.000000      1.000000       0.000000      0.000000
# 25%        0.000000      5.000000       2.000000      0.000000
# 50%        0.000000     12.000000       3.000000     25.000000
# 75%        0.000000     17.000000       5.000000    215.000000
# max     1776.000000     99.000000      80.000000  30500.000000
#
#        construction_year
# count       59400.000000
# mean         1300.652475
# std           951.620547
# min             0.000000
# 25%             0.000000
# 50%          1986.000000
# 75%          2004.000000
# max          2013.000000

# %% [markdown]
# There are only 10 numerical columns. I will elect to get rid of 'num_private' due to its confusing distribution(or lackof)

# %%
df.drop(['num_private'], axis = 1, inplace = True)
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name                    basin  ...  \
# 0  34.938093  -9.856322                  none               Lake Nyasa  ...
# 1  34.698766  -2.147466              Zahanati            Lake Victoria  ...
# 2  37.460664  -3.821329           Kwa Mahundi                  Pangani  ...
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  ...
# 4  31.130847  -1.825359               Shuleni            Lake Victoria  ...
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
# 3          soft          good           dry             dry
# 4          soft          good      seasonal        seasonal
#
#                  source           source_type  source_class  \
# 0                spring                spring   groundwater
# 1  rainwater harvesting  rainwater harvesting       surface
# 2                   dam                   dam       surface
# 3           machine dbh              borehole   groundwater
# 4  rainwater harvesting  rainwater harvesting       surface
#
#                waterpoint_type waterpoint_type_group    status_group
# 0           communal standpipe    communal standpipe      functional
# 1           communal standpipe    communal standpipe      functional
# 2  communal standpipe multiple    communal standpipe      functional
# 3  communal standpipe multiple    communal standpipe  non functional
# 4           communal standpipe    communal standpipe      functional
#
# [5 rows x 40 columns]

# %% [markdown]
# # 2) Data Cleaning

# %% [markdown]
# We are now going to proceed with the Data Cleaning Process. Throughout this, we will investigate the following:
#
# - Casting columns to the appropriate data types
# - Identifying and dealing with null values appropriately
# - Checking for Outliers and filtering dataset further
# - Dealing with categorical variables

# %% [markdown]
# <b>1) Casting columns to the appropriate data types</b>

# %% [markdown]
# Check index and column dtypes to identify which data types are not accurate

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   basin                  59400 non-null  object
#  10  subvillage             59029 non-null  object
#  11  region                 59400 non-null  object
#  12  region_code            59400 non-null  int64
#  13  district_code          59400 non-null  int64
#  14  lga                    59400 non-null  object
#  15  ward                   59400 non-null  object
#  16  population             59400 non-null  int64
#  17  public_meeting         56066 non-null  object
#  18  recorded_by            59400 non-null  object
#  19  scheme_management      55523 non-null  object
#  20  scheme_name            31234 non-null  object
#  21  permit                 56344 non-null  object
#  22  construction_year      59400 non-null  int64
#  23  extraction_type        59400 non-null  object
#  24  extraction_type_group  59400 non-null  object
#  25  extraction_type_class  59400 non-null  object
#  26  management             59400 non-null  object
#  27  management_group       59400 non-null  object
#  28  payment                59400 non-null  object
#  29  payment_type           59400 non-null  object
#  30  water_quality          59400 non-null  object
#  31  quality_group          59400 non-null  object
#  32  quantity               59400 non-null  object
#  33  quantity_group         59400 non-null  object
#  34  source                 59400 non-null  object
#  35  source_type            59400 non-null  object
#  36  source_class           59400 non-null  object
#  37  waterpoint_type        59400 non-null  object
#  38  waterpoint_type_group  59400 non-null  object
#  39  status_group           59400 non-null  object
# dtypes: float64(3), int64(6), object(31)
# memory usage: 18.1+ MB

# %% [markdown]
# Only one variable needs to be changed to the appropriate data type:
#    - Data_recorded: needs to be converted to datatime

# %%
# Convert data_recorded column to datetime
df['date_recorded'] = pd.to_datetime(df['date_recorded'])

# %%
print(df.date_recorded.dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# <b>2) Identifying and dealing with null values appropriately

# %% [markdown]
# Before figuring out the NA values, I want to take a closer look at several different pairings of variables that seem to be repeated based on the kaggle data set's descriptions of the columns.

# %%
df[['subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward']]
# Out:
#          subvillage       region  region_code  district_code             lga  \
# 0          Mnyusi B       Iringa           11              5          Ludewa
# 1           Nyamara         Mara           20              2       Serengeti
# 2           Majengo      Manyara           21              4       Simanjiro
# 3        Mahakamani       Mtwara           90             63        Nanyumbu
# 4        Kyanyamisa       Kagera           18              1         Karagwe
# ...             ...          ...          ...            ...             ...
# 59395      Kiduruni  Kilimanjaro            3              5             Hai
# 59396      Igumbilo       Iringa           11              4          Njombe
# 59397     Madungulu        Mbeya           12              7         Mbarali
# 59398        Mwinyi       Dodoma            1              4        Chamwino
# 59399  Kikatanyemba     Morogoro            5              2  Morogoro Rural
#
#                    ward
# 0              Mundindi
# 1                 Natta
# 2               Ngorika
# 3              Nanyumbu
# 4            Nyakasimbi
# ...                 ...
# 59395  Masama Magharibi
# 59396            Ikondo
# 59397           Chimala
# 59398      Mvumi Makulu
# 59399        Ngerengere
#
# [59400 rows x 6 columns]

# %% [markdown]
# it seems redundant to keep both region_code and district_code, so let's get rid of one of them. We will keep region and subvillage because they provide meaningful information. Lga presumably stands for local government authority (the location of it). A ward is an administrative structure for one single town or portion of a bigger town

# %%
df.drop('district_code', axis = 1, inplace = True)

# %%
df[['scheme_management', 'scheme_name']]
# Out:
#       scheme_management                  scheme_name
# 0                   VWC                        Roman
# 1                 Other                          NaN
# 2                   VWC  Nyumba ya mungu pipe scheme
# 3                   VWC                          NaN
# 4                   NaN                          NaN
# ...                 ...                          ...
# 59395       Water Board       Losaa Kia water supply
# 59396               VWC  Ikondo electrical water sch
# 59397               VWC                          NaN
# 59398               VWC                          NaN
# 59399               VWC                          NaN
#
# [59400 rows x 2 columns]

# %% [markdown]
# Scheme_management and scheme_name are both relatively similar features, as they both list out who operates the waterpoint. With this in mind, let's get rid of one of the two columns, and I will get rid of scheme_name because it lacks many more values than scheme_management.

# %%
df.drop('scheme_name', axis = 1, inplace = True)

# %%
df[['extraction_type_group', 'extraction_type_class', 'extraction_type']]
# Out:
#       extraction_type_group extraction_type_class extraction_type
# 0                   gravity               gravity         gravity
# 1                   gravity               gravity         gravity
# 2                   gravity               gravity         gravity
# 3               submersible           submersible     submersible
# 4                   gravity               gravity         gravity
# ...                     ...                   ...             ...
# 59395               gravity               gravity         gravity
# 59396               gravity               gravity         gravity
# 59397                swn 80              handpump          swn 80
# 59398           nira/tanira              handpump     nira/tanira
# 59399           nira/tanira              handpump     nira/tanira
#
# [59400 rows x 3 columns]

# %% [markdown]
# All three features are very similar, but extraction_type and extraction_type_group seem to be identical as opposed to extraction_type_class, so since there are more extraction type values that agree with the extraction_type_group and extraction_type, I will choose one of these features to keep and discard the other two

# %%
df.drop(['extraction_type_group', 'extraction_type_class'], axis = 1, inplace = True)

# %%
df[['management', 'management_group']]
# Out:
#         management management_group
# 0              vwc       user-group
# 1              wug       user-group
# 2              vwc       user-group
# 3              vwc       user-group
# 4            other            other
# ...            ...              ...
# 59395  water board       user-group
# 59396          vwc       user-group
# 59397          vwc       user-group
# 59398          vwc       user-group
# 59399          vwc       user-group
#
# [59400 rows x 2 columns]

# %% [markdown]
# I noticed that these features seem to tell the same information as 'scheme_management', so I will discard both of these columns as they are not adding any relevant information.

# %%
df.drop(['management', 'management_group'], axis = 1, inplace = True)

# %%
df[['payment', 'payment_type']]
# Out:
#                      payment payment_type
# 0               pay annually     annually
# 1                  never pay    never pay
# 2             pay per bucket   per bucket
# 3                  never pay    never pay
# 4                  never pay    never pay
# ...                      ...          ...
# 59395         pay per bucket   per bucket
# 59396           pay annually     annually
# 59397            pay monthly      monthly
# 59398              never pay    never pay
# 59399  pay when scheme fails   on failure
#
# [59400 rows x 2 columns]

# %% [markdown]
# These variables spit out the exact same information, but payment adds a extra 'pay' at the start of each row so I will delete this column as I want my data to be less messy.

# %%
df.drop('payment', axis = 1, inplace = True)

# %%
df[['water_quality', 'quality_group']]
# Out:
#       water_quality quality_group
# 0              soft          good
# 1              soft          good
# 2              soft          good
# 3              soft          good
# 4              soft          good
# ...             ...           ...
# 59395          soft          good
# 59396          soft          good
# 59397      fluoride      fluoride
# 59398          soft          good
# 59399         salty         salty
#
# [59400 rows x 2 columns]

# %% [markdown]
# These features seem to tell the exact same information, except water_quality has 'soft' which can be misleading in terms of its context intepretation. Let's keep the quality_group because it has 'good' instead of 'soft' for water quality. Let's also change the quality_group name to water_quality after dropping that feature.

# %%
df.drop('water_quality', axis = 1, inplace = True)

# %%
df.rename(columns = {'quality_group': 'water_quality'}, inplace = True)

# %%
df[['quantity', 'quantity_group']]
# Out:
#            quantity quantity_group
# 0            enough         enough
# 1      insufficient   insufficient
# 2            enough         enough
# 3               dry            dry
# 4          seasonal       seasonal
# ...             ...            ...
# 59395        enough         enough
# 59396        enough         enough
# 59397        enough         enough
# 59398  insufficient   insufficient
# 59399        enough         enough
#
# [59400 rows x 2 columns]

# %% [markdown]
# Drop one of these features and rename it to water_quantity

# %%
df.drop('quantity_group', axis = 1, inplace = True)

# %%
df.rename(columns = {'quantity': 'water_quantity'}, inplace = True)

# %%
df[['source_type', 'source_class', 'source']]
# Out:
#                 source_type source_class                source
# 0                    spring  groundwater                spring
# 1      rainwater harvesting      surface  rainwater harvesting
# 2                       dam      surface                   dam
# 3                  borehole  groundwater           machine dbh
# 4      rainwater harvesting      surface  rainwater harvesting
# ...                     ...          ...                   ...
# 59395                spring  groundwater                spring
# 59396            river/lake      surface                 river
# 59397              borehole  groundwater           machine dbh
# 59398          shallow well  groundwater          shallow well
# 59399          shallow well  groundwater          shallow well
#
# [59400 rows x 3 columns]

# %% [markdown]
# source_type and source are more similar to each other than source_class, so let's get rid of source_class. Let's also get rid of source_type because it is more confusing because it has values of river/lake in some rows.

# %%
df.drop(['source_type', 'source_class'], axis = 1, inplace = True)

# %%
df[['waterpoint_type', 'waterpoint_type_group']]
# Out:
#                    waterpoint_type waterpoint_type_group
# 0               communal standpipe    communal standpipe
# 1               communal standpipe    communal standpipe
# 2      communal standpipe multiple    communal standpipe
# 3      communal standpipe multiple    communal standpipe
# 4               communal standpipe    communal standpipe
# ...                            ...                   ...
# 59395           communal standpipe    communal standpipe
# 59396           communal standpipe    communal standpipe
# 59397                    hand pump             hand pump
# 59398                    hand pump             hand pump
# 59399                    hand pump             hand pump
#
# [59400 rows x 2 columns]

# %% [markdown]
# Get rid of one of these

# %%
df.drop('waterpoint_type_group', axis = 1, inplace = True)

# %% [markdown]
# Now that we have manually discarded duplicated features, let's take a preview of the new dataset before we deal with the NA values

# %%
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name                    basin  ...  \
# 0  34.938093  -9.856322                  none               Lake Nyasa  ...
# 1  34.698766  -2.147466              Zahanati            Lake Victoria  ...
# 2  37.460664  -3.821329           Kwa Mahundi                  Pangani  ...
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  ...
# 4  31.130847  -1.825359               Shuleni            Lake Victoria  ...
#
#   scheme_management permit  construction_year extraction_type payment_type  \
# 0               VWC  False               1999         gravity     annually
# 1             Other   True               2010         gravity    never pay
# 2               VWC   True               2009         gravity   per bucket
# 3               VWC   True               1986     submersible    never pay
# 4               NaN   True                  0         gravity    never pay
#
#    water_quality water_quantity                source  \
# 0           good         enough                spring
# 1           good   insufficient  rainwater harvesting
# 2           good         enough                   dam
# 3           good            dry           machine dbh
# 4           good       seasonal  rainwater harvesting
#
#                waterpoint_type    status_group
# 0           communal standpipe      functional
# 1           communal standpipe      functional
# 2  communal standpipe multiple      functional
# 3  communal standpipe multiple  non functional
# 4           communal standpipe      functional
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 59400 non-null  int64
#  1   amount_tsh         59400 non-null  float64
#  2   date_recorded      59400 non-null  datetime64[ns]
#  3   funder             55765 non-null  object
#  4   gps_height         59400 non-null  int64
#  5   installer          55745 non-null  object
#  6   longitude          59400 non-null  float64
#  7   latitude           59400 non-null  float64
#  8   wpt_name           59400 non-null  object
#  9   basin              59400 non-null  object
#  10  subvillage         59029 non-null  object
#  11  region             59400 non-null  object
#  12  region_code        59400 non-null  int64
#  13  lga                59400 non-null  object
#  14  ward               59400 non-null  object
#  15  population         59400 non-null  int64
#  16  public_meeting     56066 non-null  object
#  17  recorded_by        59400 non-null  object
#  18  scheme_management  55523 non-null  object
#  19  permit             56344 non-null  object
#  20  construction_year  59400 non-null  int64
#  21  extraction_type    59400 non-null  object
#  22  payment_type       59400 non-null  object
#  23  water_quality      59400 non-null  object
#  24  water_quantity     59400 non-null  object
#  25  source             59400 non-null  object
#  26  waterpoint_type    59400 non-null  object
#  27  status_group       59400 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(19)
# memory usage: 12.7+ MB

# %%
# Check for any NA values present in any columns
df.isnull().sum()
# Out:
# id                      0
# amount_tsh              0
# date_recorded           0
# funder               3635
# gps_height              0
# installer            3655
# longitude               0
# latitude                0
# wpt_name                0
# basin                   0
# subvillage            371
# region                  0
# region_code             0
# lga                     0
# ward                    0
# population              0
# public_meeting       3334
# recorded_by             0
# scheme_management    3877
# permit               3056
# construction_year       0
# extraction_type         0
# payment_type            0
# water_quality           0
# water_quantity          0
# source                  0
# waterpoint_type         0
# status_group            0
# dtype: int64

# %% [markdown]
# The following features have NA values present:
#  - funder
#  - installer
#  - subvillage
#  - public_meeting
#  - scheme_management
#  - permit
#
#  Dealing with these values can be an issue, as they are all of the data type 'object'. Let's take a look at what percentage of the data is missing values for these features.

# %%
na_columns = ['funder', 'installer', 'subvillage', 'public_meeting', 'scheme_management', 'permit']
for col in na_columns:
    print('*' * 100)
    print(df[col].isnull().value_counts(normalize = True) * 100)
# Out:
# ****************************************************************************************************
# False    93.880471
# True      6.119529
# Name: funder, dtype: float64
# ****************************************************************************************************
# False    93.846801
# True      6.153199
# Name: installer, dtype: float64
# ****************************************************************************************************
# False    99.375421
# True      0.624579
# Name: subvillage, dtype: float64
# ****************************************************************************************************
# False    94.387205
# True      5.612795
# Name: public_meeting, dtype: float64
# ****************************************************************************************************
# False    93.473064
# True      6.526936
# Name: scheme_management, dtype: float64
# ****************************************************************************************************
# False    94.855219
# True      5.144781
# Name: permit, dtype: float64

# %% [markdown]
# Excluding permit, on average, the NA values in each respective column is approx 6%. Because these NA values are of object data type we can't really fill in these values with anything. Given that the NA values are an insignificant amount, we can can replace these values with the string 'Not known'

# %%
df.loc[:, ['funder', 'installer', 'subvillage', 'public_meeting', 'scheme_management', 'permit']] = df.loc[:, ['funder', 'installer', 'subvillage', 'public_meeting', 'scheme_management', 'permit']].fillna('Not Known')

# %%
df.isnull().sum()
# Out:
# id                   0
# amount_tsh           0
# date_recorded        0
# funder               0
# gps_height           0
# installer            0
# longitude            0
# latitude             0
# wpt_name             0
# basin                0
# subvillage           0
# region               0
# region_code          0
# lga                  0
# ward                 0
# population           0
# public_meeting       0
# recorded_by          0
# scheme_management    0
# permit               0
# construction_year    0
# extraction_type      0
# payment_type         0
# water_quality        0
# water_quantity       0
# source               0
# waterpoint_type      0
# status_group         0
# dtype: int64

# %% [markdown]
# <b>3) Checking for Outliers and filtering dataset further</b>

# %%
df.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#         region_code    population  construction_year
# count  59400.000000  59400.000000       59400.000000
# mean      15.297003    179.909983        1300.652475
# std       17.587406    471.482176         951.620547
# min        1.000000      0.000000           0.000000
# 25%        5.000000      0.000000           0.000000
# 50%       12.000000     25.000000        1986.000000
# 75%       17.000000    215.000000        2004.000000
# max       99.000000  30500.000000        2013.000000

# %%
numerical_cols = ['gps_height', 'region_code', 'population', 'construction_year']
for col in numerical_cols:
    print('{}'.format(col))
    print(df[col].value_counts(normalize = True))
    print('-' * 100)
    print('\n')
# Out:
# gps_height
#  0       0.344074
# -15      0.001010
# -16      0.000926
# -13      0.000926
# -20      0.000875
#            ...
#  2285    0.000017
#  2424    0.000017
#  2552    0.000017
#  2413    0.000017
#  2385    0.000017
# Name: gps_height, Length: 2428, dtype: float64
# ----------------------------------------------------------------------------------------------------
#
#
# region_code
# 11    0.089226
# 17    0.084360
# 12    0.078098
# 3     0.073721
# 5     0.068013
# 18    0.055960
# 19    0.051296
# 2     0.050909
# 16    0.047407
# 10    0.044444
# 4     0.042306
# 1     0.037054
# 13    0.035236
# 14    0.033316
# 20    0.033148
# 15    0.030438
# 6     0.027088
# 21    0.026650
# 80    0.020842
# 60    0.017256
# 90    0.015438
# 7     0.013552
# 99    0.007121
# 9     0.006566
# 24    0.005488
# 8     0.005051
# 40    0.000017
# Name: region_code, dtype: float64
# ----------------------------------------------------------------------------------------------------
#
#
# population
# 0       0.359949
# 1       0.118266
# 200     0.032660
# 150     0.031852
# 250     0.028300
#           ...
# 3241    0.000017
# 1960    0.000017
# 1685    0.000017
# 2248    0.000017
# 1439    0.000017
# Name: population, Length: 1049, dtype: float64
# ----------------------------------------------------------------------------------------------------
#
#
# construction_year
# 0       0.348636
# 2010    0.044529
# 2008    0.043990
# 2009    0.042643
# 2000    0.035202
# 2007    0.026717
# 2006    0.024764
# 2003    0.021650
# 2011    0.021145
# 2004    0.018906
# 2012    0.018249
# 2002    0.018098
# 1978    0.017458
# 1995    0.017071
# 2005    0.017020
# 1999    0.016481
# 1998    0.016263
# 1990    0.016061
# 1985    0.015909
# 1980    0.013653
# 1996    0.013653
# 1984    0.013114
# 1982    0.012525
# 1994    0.012424
# 1972    0.011919
# 1974    0.011380
# 1997    0.010842
# 1992    0.010774
# 1993    0.010236
# 2001    0.009091
# 1988    0.008771
# 1983    0.008215
# 1975    0.007357
# 1986    0.007306
# 1976    0.006970
# 1970    0.006919
# 1991    0.005455
# 1989    0.005320
# 1987    0.005084
# 1981    0.004007
# 1977    0.003401
# 1979    0.003232
# 1973    0.003098
# 2013    0.002963
# 1971    0.002441
# 1960    0.001717
# 1967    0.001481
# 1963    0.001431
# 1968    0.001296
# 1969    0.000993
# 1964    0.000673
# 1962    0.000505
# 1961    0.000354
# 1965    0.000320
# 1966    0.000286
# Name: construction_year, dtype: float64
# ----------------------------------------------------------------------------------------------------

# %%
# bin the construction years using dummy var, and make 0's not known if there is no relationship
# put your continous variables in the borouta algorithm

# %% [markdown]
# There are many situations where the majority of the data set is comprised of values being 0, but these could actually be meaningful information, so let's keep these values for now except construction year. Having a construction year or 0 does not provide any information at all, so let's bin the years together first

# %%
cat_columns = []
for col in df.columns:
    if df[col].dtype == 'object':
        cat_columns.append(col)
cat_columns
# Out:
# ['funder',
#  'installer',
#  'wpt_name',
#  'basin',
#  'subvillage',
#  'region',
#  'lga',
#  'ward',
#  'public_meeting',
#  'recorded_by',
#  'scheme_management',
#  'permit',
#  'extraction_type',
#  'payment_type',
#  'water_quality',
#  'water_quantity',
#  'source',
#  'waterpoint_type',
#  'status_group']

# %%
for col in cat_columns:
    print('{}'.format(col))
    print(df[col].unique())
    print('-' * 100)
    print('\n')
# Out:
# funder
# ['Roman' 'Grumeti' 'Lottery Club' ... 'Dina' 'Brown' 'Samlo']
# ----------------------------------------------------------------------------------------------------
#
#
# installer
# ['Roman' 'GRUMETI' 'World vision' ... 'Dina' 'brown' 'SELEPTA']
# ----------------------------------------------------------------------------------------------------
#
#
# wpt_name
# ['none' 'Zahanati' 'Kwa Mahundi' ... 'Kwa Yahona Kuvala' 'Mshoro'
#  'Kwa Mzee Lugawa']
# ----------------------------------------------------------------------------------------------------
#
#
# basin
# ['Lake Nyasa' 'Lake Victoria' 'Pangani' 'Ruvuma / Southern Coast'
#  'Internal' 'Lake Tanganyika' 'Wami / Ruvu' 'Rufiji' 'Lake Rukwa']
# ----------------------------------------------------------------------------------------------------
#
#
# subvillage
# ['Mnyusi B' 'Nyamara' 'Majengo' ... 'Itete B' 'Maore Kati' 'Kikatanyemba']
# ----------------------------------------------------------------------------------------------------
#
#
# region
# ['Iringa' 'Mara' 'Manyara' 'Mtwara' 'Kagera' 'Tanga' 'Shinyanga' 'Tabora'
#  'Pwani' 'Ruvuma' 'Kilimanjaro' 'Rukwa' 'Mwanza' 'Kigoma' 'Lindi' 'Dodoma'
#  'Arusha' 'Mbeya' 'Singida' 'Morogoro' 'Dar es Salaam']
# ----------------------------------------------------------------------------------------------------
#
#
# lga
# ['Ludewa' 'Serengeti' 'Simanjiro' 'Nanyumbu' 'Karagwe' 'Mkinga'
#  'Shinyanga Rural' 'Kahama' 'Tabora Urban' 'Mkuranga' 'Namtumbo' 'Maswa'
#  'Siha' 'Meatu' 'Sumbawanga Rural' 'Njombe' 'Ukerewe' 'Bariadi' 'Same'
#  'Kigoma Rural' 'Moshi Rural' 'Lindi Rural' 'Rombo' 'Chamwino' 'Bagamoyo'
#  'Mafia' 'Arusha Rural' 'Kyela' 'Kondoa' 'Kilolo' 'Kibondo' 'Makete'
#  'Singida Rural' 'Masasi' 'Rungwe' 'Moshi Urban' 'Geita' 'Mbulu'
#  'Bukoba Rural' 'Muheza' 'Lushoto' 'Meru' 'Iramba' 'Kilombero' 'Mbarali'
#  'Kasulu' 'Bukoba Urban' 'Korogwe' 'Bukombe' 'Morogoro Rural' 'Kishapu'
#  'Musoma Rural' 'Sengerema' 'Iringa Rural' 'Muleba' 'Dodoma Urban'
#  'Ruangwa' 'Hanang' 'Misenyi' 'Missungwi' 'Songea Rural' 'Tanga' 'Tunduru'
#  'Hai' 'Mwanga' 'Chato' 'Biharamulo' 'Ileje' 'Mpwapwa' 'Mvomero' 'Bunda'
#  'Kiteto' 'Longido' 'Urambo' 'Mbozi' 'Sikonge' 'Ilala' 'Tarime' 'Temeke'
#  'Mbeya Rural' 'Magu' 'Manyoni' 'Igunga' 'Kilosa' 'Babati' 'Chunya'
#  'Mufindi' 'Mtwara Rural' 'Ngara' 'Karatu' 'Mpanda' 'Kibaha'
#  'Singida Urban' 'Newala' 'Nzega' 'Nkasi' 'Bahi' 'Mbinga' 'Ulanga'
#  'Sumbawanga Urban' 'Morogoro Urban' 'Tandahimba' 'Kisarawe'
#  'Mtwara Urban' 'Kilwa' 'Liwale' 'Kongwa' 'Uyui' 'Rufiji' 'Kwimba'
#  'Monduli' 'Shinyanga Urban' 'Ngorongoro' 'Handeni' 'Rorya' 'Pangani'
#  'Lindi Urban' 'Nachingwea' 'Kinondoni' 'Kigoma Urban' 'Ilemela' 'Kilindi'
#  'Arusha Urban' 'Songea Urban' 'Nyamagana']
# ----------------------------------------------------------------------------------------------------
#
#
# ward
# ['Mundindi' 'Natta' 'Ngorika' ... 'Chinugulu' 'Nyamtinga' 'Kinungu']
# ----------------------------------------------------------------------------------------------------
#
#
# public_meeting
# [True 'Not Known' False]
# ----------------------------------------------------------------------------------------------------
#
#
# recorded_by
# ['GeoData Consultants Ltd']
# ----------------------------------------------------------------------------------------------------
#
#
# scheme_management
# ['VWC' 'Other' 'Not Known' 'Private operator' 'WUG' 'Water Board' 'WUA'
#  'Water authority' 'Company' 'Parastatal' 'Trust' 'SWC' 'None']
# ----------------------------------------------------------------------------------------------------
#
#
# permit
# [False True 'Not Known']
# ----------------------------------------------------------------------------------------------------
#
#
# extraction_type
# ['gravity' 'submersible' 'swn 80' 'nira/tanira' 'india mark ii' 'other'
#  'ksb' 'mono' 'windmill' 'afridev' 'other - rope pump' 'india mark iii'
#  'other - swn 81' 'other - play pump' 'cemo' 'climax' 'walimi'
#  'other - mkulima/shinyanga']
# ----------------------------------------------------------------------------------------------------
#
#
# payment_type
# ['annually' 'never pay' 'per bucket' 'unknown' 'on failure' 'other'
#  'monthly']
# ----------------------------------------------------------------------------------------------------
#
#
# water_quality
# ['good' 'salty' 'milky' 'unknown' 'fluoride' 'colored']
# ----------------------------------------------------------------------------------------------------
#
#
# water_quantity
# ['enough' 'insufficient' 'dry' 'seasonal' 'unknown']
# ----------------------------------------------------------------------------------------------------
#
#
# source
# ['spring' 'rainwater harvesting' 'dam' 'machine dbh' 'other'
#  'shallow well' 'river' 'hand dtw' 'lake' 'unknown']
# ----------------------------------------------------------------------------------------------------
#
#
# waterpoint_type
# ['communal standpipe' 'communal standpipe multiple' 'hand pump' 'other'
#  'improved spring' 'cattle trough' 'dam']
# ----------------------------------------------------------------------------------------------------
#
#
# status_group
# ['functional' 'non functional' 'functional needs repair']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Now we will look into performing dummy variable transformations. Just like we saw in the last project, I will only perform dummy transformations on nominal variables. I have deemed the following to be nominal:
#
#  - funder
#  - installer
#  - wpt_name
#  - basin
#  - subvillage
#  - region
#  - lga
#  - ward
#  - recorded_by
#  - scheme_management
#  - extraction_type
#  - payment_type
#  - water_quality
#  - source
#  - waterpoint_type

# %%
# find the top 5 most frequently seen values to see if transforming them using dummy variables is appropriate

# %%
for col in cat_columns:
    print('The Percentage of the top 5 most frequently seen values in {} are: '.format(col))
    print(df[col].value_counts(normalize = True).head(5).sum() * 100)
    print('-' * 100)
# Out:
# The Percentage of the top 5 most frequently seen values in funder are:
# 32.72053872053872
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in installer are:
# 42.33670033670034
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in wpt_name are:
# 11.782828282828282
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in basin are:
# 69.66498316498317
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in subvillage are:
# 3.8047138047138054
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in region are:
# 39.22558922558922
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in lga are:
# 12.271043771043772
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in ward are:
# 2.085858585858586
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in public_meeting are:
# 100.0
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in recorded_by are:
# 100.0
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in scheme_management are:
# 87.39393939393939
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in permit are:
# 100.0
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in extraction_type are:
# 83.83501683501683
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in payment_type are:
# 92.0942760942761
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in water_quality are:
# 99.63468013468014
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in water_quantity are:
# 99.99999999999999
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in source are:
# 95.66835016835016
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in waterpoint_type are:
# 99.79292929292929
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in status_group are:
# 100.0
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# funder, installer, wpt_name, ward, lga need further investigation, but as for the rest of the variables, we can filter out the rest of the unwanted data

# %%
filtered_cat_columns = ['basin', 'public_meeting', 'recorded_by', 'scheme_management', 'permit', 'extraction_type', 'payment_type', 'water_quality', 'water_quantity', 'source', 'waterpoint_type', 'status_group']
for col in filtered_cat_columns:
    print('The Top 5 most frequently seen values in {} are: '.format(col))
    print(df[col].value_counts(normalize = True).head(5))
    print('-' * 100)
# Out:
# The Top 5 most frequently seen values in basin are:
# Lake Victoria      0.172525
# Pangani            0.150505
# Rufiji             0.134276
# Internal           0.131061
# Lake Tanganyika    0.108283
# Name: basin, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in public_meeting are:
# True         0.858771
# False        0.085101
# Not Known    0.056128
# Name: public_meeting, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in recorded_by are:
# GeoData Consultants Ltd    1.0
# Name: recorded_by, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in scheme_management are:
# VWC                0.619411
# WUG                0.087643
# Not Known          0.065269
# Water authority    0.053081
# WUA                0.048535
# Name: scheme_management, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in permit are:
# True         0.654074
# False        0.294478
# Not Known    0.051448
# Name: permit, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in extraction_type are:
# gravity        0.450842
# nira/tanira    0.137273
# other          0.108249
# submersible    0.080202
# swn 80         0.061785
# Name: extraction_type, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in payment_type are:
# never pay     0.426734
# per bucket    0.151263
# monthly       0.139731
# unknown       0.137323
# on failure    0.065892
# Name: payment_type, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in water_quality are:
# good       0.855522
# salty      0.087458
# unknown    0.031582
# milky      0.013535
# colored    0.008249
# Name: water_quality, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in water_quantity are:
# enough          0.558687
# insufficient    0.254697
# dry             0.105152
# seasonal        0.068182
# unknown         0.013283
# Name: water_quantity, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in source are:
# spring                  0.286549
# shallow well            0.283232
# machine dbh             0.186448
# river                   0.161818
# rainwater harvesting    0.038636
# Name: source, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in waterpoint_type are:
# communal standpipe             0.480168
# hand pump                      0.294411
# other                          0.107407
# communal standpipe multiple    0.102744
# improved spring                0.013199
# Name: waterpoint_type, dtype: float64
# ----------------------------------------------------------------------------------------------------
# The Top 5 most frequently seen values in status_group are:
# functional                 0.543081
# non functional             0.384242
# functional needs repair    0.072677
# Name: status_group, dtype: float64
# ----------------------------------------------------------------------------------------------------

# %%
filtered_drop_basin = df.loc[(~df['basin'].str.contains('Victoria')) & (~df['basin'].str.contains('Pangani')) 
                    & (~df['basin'].str.contains('Rufiji')) & (~df['basin'].str.contains('Internal')) 
                    & (~df['basin'].str.contains('Tanganyika'))].index
df.drop(filtered_drop_basin, inplace = True)

# %%
df.head()
# Out:
#       id  amount_tsh date_recorded               funder  gps_height  \
# 1   8776         0.0    2013-03-06              Grumeti        1399
# 2  34310        25.0    2013-02-25         Lottery Club         686
# 4  19728         0.0    2011-07-13          Action In A           0
# 5   9944        20.0    2011-03-13  Mkinga Distric Coun           0
# 6  19816         0.0    2012-10-01                 Dwsp           0
#
#       installer  longitude  latitude     wpt_name          basin  ...  \
# 1       GRUMETI  34.698766 -2.147466     Zahanati  Lake Victoria  ...
# 2  World vision  37.460664 -3.821329  Kwa Mahundi        Pangani  ...
# 4       Artisan  31.130847 -1.825359      Shuleni  Lake Victoria  ...
# 5           DWE  39.172796 -4.765587       Tajiri        Pangani  ...
# 6          DWSP  33.362410 -3.766365   Kwa Ngomho       Internal  ...
#
#   scheme_management permit  construction_year extraction_type payment_type  \
# 1             Other   True               2010         gravity    never pay
# 2               VWC   True               2009         gravity   per bucket
# 4         Not Known   True                  0         gravity    never pay
# 5               VWC   True               2009     submersible   per bucket
# 6               VWC   True                  0          swn 80    never pay
#
#    water_quality water_quantity                source  \
# 1           good   insufficient  rainwater harvesting
# 2           good         enough                   dam
# 4           good       seasonal  rainwater harvesting
# 5          salty         enough                 other
# 6           good         enough           machine dbh
#
#                waterpoint_type    status_group
# 1           communal standpipe      functional
# 2  communal standpipe multiple      functional
# 4           communal standpipe      functional
# 5  communal standpipe multiple      functional
# 6                    hand pump  non functional
#
# [5 rows x 28 columns]

# %%
# Scheme Management
filtered_drop_management = df.loc[(~df['scheme_management'].str.contains('VWC')) & (~df['scheme_management'].str.contains('WUG')) 
         & (~df['scheme_management'].str.contains('Not Known')) & (~df['scheme_management'].str.contains('Water authority')) 
         & (~df['scheme_management'].str.contains('WUA'))].index
df.drop(filtered_drop_management, inplace = True)
df.head()
# Out:
#       id  amount_tsh date_recorded               funder  gps_height  \
# 2  34310        25.0    2013-02-25         Lottery Club         686
# 4  19728         0.0    2011-07-13          Action In A           0
# 5   9944        20.0    2011-03-13  Mkinga Distric Coun           0
# 6  19816         0.0    2012-10-01                 Dwsp           0
# 7  54551         0.0    2012-10-09                Rwssp           0
#
#       installer  longitude  latitude      wpt_name            basin  ...  \
# 2  World vision  37.460664 -3.821329   Kwa Mahundi          Pangani  ...
# 4       Artisan  31.130847 -1.825359       Shuleni    Lake Victoria  ...
# 5           DWE  39.172796 -4.765587        Tajiri          Pangani  ...
# 6          DWSP  33.362410 -3.766365    Kwa Ngomho         Internal  ...
# 7           DWE  32.620617 -4.226198  Tushirikiane  Lake Tanganyika  ...
#
#   scheme_management permit  construction_year extraction_type payment_type  \
# 2               VWC   True               2009         gravity   per bucket
# 4         Not Known   True                  0         gravity    never pay
# 5               VWC   True               2009     submersible   per bucket
# 6               VWC   True                  0          swn 80    never pay
# 7         Not Known   True                  0     nira/tanira      unknown
#
#    water_quality water_quantity                source  \
# 2           good         enough                   dam
# 4           good       seasonal  rainwater harvesting
# 5          salty         enough                 other
# 6           good         enough           machine dbh
# 7          milky         enough          shallow well
#
#                waterpoint_type    status_group
# 2  communal standpipe multiple      functional
# 4           communal standpipe      functional
# 5  communal standpipe multiple      functional
# 6                    hand pump  non functional
# 7                    hand pump  non functional
#
# [5 rows x 28 columns]

# %%
# Extraction type
filtered_drop_extraction = df.loc[(~df['extraction_type'].str.contains('gravity')) & (~df['extraction_type'].str.contains('nira/tanira')) 
         & (~df['extraction_type'].str.contains('other')) & (~df['extraction_type'].str.contains('submersible')) 
         & (~df['extraction_type'].str.contains('swn 80'))].index
df.drop(filtered_drop_extraction, inplace = True)
df.head()
# Out:
#       id  amount_tsh date_recorded               funder  gps_height  \
# 2  34310        25.0    2013-02-25         Lottery Club         686
# 4  19728         0.0    2011-07-13          Action In A           0
# 5   9944        20.0    2011-03-13  Mkinga Distric Coun           0
# 6  19816         0.0    2012-10-01                 Dwsp           0
# 7  54551         0.0    2012-10-09                Rwssp           0
#
#       installer  longitude  latitude      wpt_name            basin  ...  \
# 2  World vision  37.460664 -3.821329   Kwa Mahundi          Pangani  ...
# 4       Artisan  31.130847 -1.825359       Shuleni    Lake Victoria  ...
# 5           DWE  39.172796 -4.765587        Tajiri          Pangani  ...
# 6          DWSP  33.362410 -3.766365    Kwa Ngomho         Internal  ...
# 7           DWE  32.620617 -4.226198  Tushirikiane  Lake Tanganyika  ...
#
#   scheme_management permit  construction_year extraction_type payment_type  \
# 2               VWC   True               2009         gravity   per bucket
# 4         Not Known   True                  0         gravity    never pay
# 5               VWC   True               2009     submersible   per bucket
# 6               VWC   True                  0          swn 80    never pay
# 7         Not Known   True                  0     nira/tanira      unknown
#
#    water_quality water_quantity                source  \
# 2           good         enough                   dam
# 4           good       seasonal  rainwater harvesting
# 5          salty         enough                 other
# 6           good         enough           machine dbh
# 7          milky         enough          shallow well
#
#                waterpoint_type    status_group
# 2  communal standpipe multiple      functional
# 4           communal standpipe      functional
# 5  communal standpipe multiple      functional
# 6                    hand pump  non functional
# 7                    hand pump  non functional
#
# [5 rows x 28 columns]

# %%
# Payment type
filtered_drop_payment = df.loc[(~df['payment_type'].str.contains('never pay')) & (~df['payment_type'].str.contains('per bucket')) 
         & (~df['payment_type'].str.contains('monthly')) & (~df['payment_type'].str.contains('unknown')) 
         & (~df['payment_type'].str.contains('on failure'))].index
df.drop(filtered_drop_payment, inplace = True)
df.head()
# Out:
#       id  amount_tsh date_recorded               funder  gps_height  \
# 2  34310        25.0    2013-02-25         Lottery Club         686
# 4  19728         0.0    2011-07-13          Action In A           0
# 5   9944        20.0    2011-03-13  Mkinga Distric Coun           0
# 6  19816         0.0    2012-10-01                 Dwsp           0
# 7  54551         0.0    2012-10-09                Rwssp           0
#
#       installer  longitude  latitude      wpt_name            basin  ...  \
# 2  World vision  37.460664 -3.821329   Kwa Mahundi          Pangani  ...
# 4       Artisan  31.130847 -1.825359       Shuleni    Lake Victoria  ...
# 5           DWE  39.172796 -4.765587        Tajiri          Pangani  ...
# 6          DWSP  33.362410 -3.766365    Kwa Ngomho         Internal  ...
# 7           DWE  32.620617 -4.226198  Tushirikiane  Lake Tanganyika  ...
#
#   scheme_management permit  construction_year extraction_type payment_type  \
# 2               VWC   True               2009         gravity   per bucket
# 4         Not Known   True                  0         gravity    never pay
# 5               VWC   True               2009     submersible   per bucket
# 6               VWC   True                  0          swn 80    never pay
# 7         Not Known   True                  0     nira/tanira      unknown
#
#    water_quality water_quantity                source  \
# 2           good         enough                   dam
# 4           good       seasonal  rainwater harvesting
# 5          salty         enough                 other
# 6           good         enough           machine dbh
# 7          milky         enough          shallow well
#
#                waterpoint_type    status_group
# 2  communal standpipe multiple      functional
# 4           communal standpipe      functional
# 5  communal standpipe multiple      functional
# 6                    hand pump  non functional
# 7                    hand pump  non functional
#
# [5 rows x 28 columns]

# %%
# Source
filtered_drop_source = df.loc[(~df['source'].str.contains('spring')) & (~df['source'].str.contains('shallow well')) 
         & (~df['source'].str.contains('machine dbh')) & (~df['source'].str.contains('river')) 
         & (~df['source'].str.contains('rainwater harvesting'))].index
df.drop(filtered_drop_source, inplace = True)
df.head()
# Out:
#        id  amount_tsh date_recorded       funder  gps_height installer  \
# 4   19728         0.0    2011-07-13  Action In A           0   Artisan
# 6   19816         0.0    2012-10-01         Dwsp           0      DWSP
# 7   54551         0.0    2012-10-09        Rwssp           0       DWE
# 9   46144         0.0    2011-08-03  Isingiro Ho           0   Artisan
# 14  53752         0.0    2012-10-20        Biore           0    WEDECO
#
#     longitude  latitude      wpt_name            basin  ... scheme_management  \
# 4   31.130847 -1.825359       Shuleni    Lake Victoria  ...         Not Known
# 6   33.362410 -3.766365    Kwa Ngomho         Internal  ...               VWC
# 7   32.620617 -4.226198  Tushirikiane  Lake Tanganyika  ...         Not Known
# 9   30.626991 -1.257051       Kwapeto    Lake Victoria  ...         Not Known
# 14  34.364073 -3.629333     Mwabasabi         Internal  ...               WUG
#
#    permit  construction_year extraction_type payment_type  water_quality  \
# 4    True                  0         gravity    never pay           good
# 6    True                  0          swn 80    never pay           good
# 7    True                  0     nira/tanira      unknown          milky
# 9    True                  0     nira/tanira    never pay           good
# 14   True                  0     nira/tanira    never pay           good
#
#    water_quantity                source     waterpoint_type    status_group
# 4        seasonal  rainwater harvesting  communal standpipe      functional
# 6          enough           machine dbh           hand pump  non functional
# 7          enough          shallow well           hand pump  non functional
# 9          enough          shallow well           hand pump      functional
# 14         enough          shallow well           hand pump      functional
#
# [5 rows x 28 columns]

# %%
filtered_drop_source = df.loc[(~df['source'].str.contains('spring')) & (~df['source'].str.contains('shallow well')) 
         & (~df['source'].str.contains('machine dbh')) & (~df['source'].str.contains('river')) 
         & (~df['source'].str.contains('rainwater harvesting'))].index
df.drop(filtered_drop_source, inplace = True)
df.head()
# Out:
#        id  amount_tsh date_recorded       funder  gps_height installer  \
# 4   19728         0.0    2011-07-13  Action In A           0   Artisan
# 6   19816         0.0    2012-10-01         Dwsp           0      DWSP
# 7   54551         0.0    2012-10-09        Rwssp           0       DWE
# 9   46144         0.0    2011-08-03  Isingiro Ho           0   Artisan
# 14  53752         0.0    2012-10-20        Biore           0    WEDECO
#
#     longitude  latitude      wpt_name            basin  ... scheme_management  \
# 4   31.130847 -1.825359       Shuleni    Lake Victoria  ...         Not Known
# 6   33.362410 -3.766365    Kwa Ngomho         Internal  ...               VWC
# 7   32.620617 -4.226198  Tushirikiane  Lake Tanganyika  ...         Not Known
# 9   30.626991 -1.257051       Kwapeto    Lake Victoria  ...         Not Known
# 14  34.364073 -3.629333     Mwabasabi         Internal  ...               WUG
#
#    permit  construction_year extraction_type payment_type  water_quality  \
# 4    True                  0         gravity    never pay           good
# 6    True                  0          swn 80    never pay           good
# 7    True                  0     nira/tanira      unknown          milky
# 9    True                  0     nira/tanira    never pay           good
# 14   True                  0     nira/tanira    never pay           good
#
#    water_quantity                source     waterpoint_type    status_group
# 4        seasonal  rainwater harvesting  communal standpipe      functional
# 6          enough           machine dbh           hand pump  non functional
# 7          enough          shallow well           hand pump  non functional
# 9          enough          shallow well           hand pump      functional
# 14         enough          shallow well           hand pump      functional
#
# [5 rows x 28 columns]

# %% [markdown]
# Now that all the data is filtered, we can now deal with the continous variables and the other categorical variables funder, installer, wpt_name, ward, lga which could not be filtered for further. We will use a algorithm called the Boruta algorithm

# %%
# Transform the status group into integers for the boruta algorithm
df['status_group'].replace({'functional': '0', 'non functional': '1', 'functional needs repair': '2'}, inplace = True)
df.head()
# Out:
#        id  amount_tsh date_recorded       funder  gps_height installer  \
# 4   19728         0.0    2011-07-13  Action In A           0   Artisan
# 6   19816         0.0    2012-10-01         Dwsp           0      DWSP
# 7   54551         0.0    2012-10-09        Rwssp           0       DWE
# 9   46144         0.0    2011-08-03  Isingiro Ho           0   Artisan
# 14  53752         0.0    2012-10-20        Biore           0    WEDECO
#
#     longitude  latitude      wpt_name            basin  ... scheme_management  \
# 4   31.130847 -1.825359       Shuleni    Lake Victoria  ...         Not Known
# 6   33.362410 -3.766365    Kwa Ngomho         Internal  ...               VWC
# 7   32.620617 -4.226198  Tushirikiane  Lake Tanganyika  ...         Not Known
# 9   30.626991 -1.257051       Kwapeto    Lake Victoria  ...         Not Known
# 14  34.364073 -3.629333     Mwabasabi         Internal  ...               WUG
#
#    permit  construction_year extraction_type payment_type  water_quality  \
# 4    True                  0         gravity    never pay           good
# 6    True                  0          swn 80    never pay           good
# 7    True                  0     nira/tanira      unknown          milky
# 9    True                  0     nira/tanira    never pay           good
# 14   True                  0     nira/tanira    never pay           good
#
#    water_quantity                source     waterpoint_type status_group
# 4        seasonal  rainwater harvesting  communal standpipe            0
# 6          enough           machine dbh           hand pump            1
# 7          enough          shallow well           hand pump            1
# 9          enough          shallow well           hand pump            0
# 14         enough          shallow well           hand pump            0
#
# [5 rows x 28 columns]

# %%
# Convert status group to integer 
df.status_group.astype({'status_group': 'int64'}).dtypes
# Out:
# dtype('int64')

# %%
# Create a dataset with just the continous variables
df_1 = df.copy()
df_1 = df_1.select_dtypes(exclude=['object'])
df_1 = df_1.drop('id', axis = 1)
df_1.head()
# Out:
#     amount_tsh date_recorded  gps_height  longitude  latitude  region_code  \
# 4          0.0    2011-07-13           0  31.130847 -1.825359           18
# 6          0.0    2012-10-01           0  33.362410 -3.766365           17
# 7          0.0    2012-10-09           0  32.620617 -4.226198           17
# 9          0.0    2011-08-03           0  30.626991 -1.257051           18
# 14         0.0    2012-10-20           0  34.364073 -3.629333           17
#
#     population  construction_year
# 4            0                  0
# 6            0                  0
# 7            0                  0
# 9            0                  0
# 14           0                  0

# %%
# Convert date_recorded into months
df_1['date_recorded'] = df_1['date_recorded'].dt.month
df_1.head()
# Out:
#     amount_tsh  date_recorded  gps_height  longitude  latitude  region_code  \
# 4          0.0              7           0  31.130847 -1.825359           18
# 6          0.0             10           0  33.362410 -3.766365           17
# 7          0.0             10           0  32.620617 -4.226198           17
# 9          0.0              8           0  30.626991 -1.257051           18
# 14         0.0             10           0  34.364073 -3.629333           17
#
#     population  construction_year
# 4            0                  0
# 6            0                  0
# 7            0                  0
# 9            0                  0
# 14           0                  0

# %%
df_1.head()
# Out:
#     amount_tsh  date_recorded  gps_height  longitude  latitude  region_code  \
# 4          0.0              7           0  31.130847 -1.825359           18
# 6          0.0             10           0  33.362410 -3.766365           17
# 7          0.0             10           0  32.620617 -4.226198           17
# 9          0.0              8           0  30.626991 -1.257051           18
# 14         0.0             10           0  34.364073 -3.629333           17
#
#     population  construction_year
# 4            0                  0
# 6            0                  0
# 7            0                  0
# 9            0                  0
# 14           0                  0

# %% [markdown]
# It looks like all the variables seems to have some degree of importance to it. So we will keep all of them for now and investigate them further in the EDA section

# %%
# Rename status_group to well_condition
df.rename(columns={'status_group': 'well_condition'}, inplace=True)

# %%
# Drop id column, and preview cleaned data set
df.drop('id', axis = 1)
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# 4             0.0    2011-07-13             Action In A           0
# 6             0.0    2012-10-01                    Dwsp           0
# 7             0.0    2012-10-09                   Rwssp           0
# 9             0.0    2011-08-03             Isingiro Ho           0
# 14            0.0    2012-10-20                   Biore           0
# ...           ...           ...                     ...         ...
# 59388         0.0    2013-01-29                   Kidep        1414
# 59390         0.0    2011-08-04                   Rudep        1715
# 59391         0.0    2013-08-03  Government Of Tanzania         540
# 59397         0.0    2011-04-11               Not Known           0
# 59398         0.0    2011-03-08                   Malec           0
#
#         installer  longitude  latitude            wpt_name            basin  \
# 4         Artisan  31.130847 -1.825359             Shuleni    Lake Victoria
# 6            DWSP  33.362410 -3.766365          Kwa Ngomho         Internal
# 7             DWE  32.620617 -4.226198        Tushirikiane  Lake Tanganyika
# 9         Artisan  30.626991 -1.257051             Kwapeto    Lake Victoria
# 14         WEDECO  34.364073 -3.629333           Mwabasabi         Internal
# ...           ...        ...       ...                 ...              ...
# 59388         DWE  30.692400 -3.593827  Kwa Philipo Kibeba  Lake Tanganyika
# 59390         DWE  31.370848 -8.258160     Kwa Mzee Atanas  Lake Tanganyika
# 59391  Government  38.044070 -4.272218                 Kwa          Pangani
# 59397   Not Known  34.017087 -8.750434             Mashine           Rufiji
# 59398        Musa  35.861315 -6.378573              Mshoro           Rufiji
#
#             subvillage  ... scheme_management  permit construction_year  \
# 4           Kyanyamisa  ...         Not Known    True                 0
# 6        Ishinabulandi  ...               VWC    True                 0
# 7      Nyawishi Center  ...         Not Known    True                 0
# 9             Mkonomre  ...         Not Known    True                 0
# 14           Mwabasabi  ...               WUG    True                 0
# ...                ...  ...               ...     ...               ...
# 59388         Kumwambu  ...               VWC    True              1995
# 59390          Kitonto  ...               VWC   False              1991
# 59391       Maore Kati  ...   Water authority    True              1967
# 59397        Madungulu  ...               VWC   False                 0
# 59398           Mwinyi  ...               VWC    True                 0
#
#       extraction_type  payment_type water_quality water_quantity  \
# 4             gravity     never pay          good       seasonal
# 6              swn 80     never pay          good         enough
# 7         nira/tanira       unknown         milky         enough
# 9         nira/tanira     never pay          good         enough
# 14        nira/tanira     never pay          good         enough
# ...               ...           ...           ...            ...
# 59388         gravity       unknown          good   insufficient
# 59390          swn 80     never pay          good   insufficient
# 59391         gravity     never pay          good         enough
# 59397          swn 80       monthly      fluoride         enough
# 59398     nira/tanira     never pay          good   insufficient
#
#                      source     waterpoint_type  well_condition
# 4      rainwater harvesting  communal standpipe               0
# 6               machine dbh           hand pump               1
# 7              shallow well           hand pump               1
# 9              shallow well           hand pump               0
# 14             shallow well           hand pump               0
# ...                     ...                 ...             ...
# 59388                spring     improved spring               0
# 59390           machine dbh           hand pump               0
# 59391                 river  communal standpipe               1
# 59397           machine dbh           hand pump               0
# 59398          shallow well           hand pump               0
#
# [26715 rows x 27 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# Questions:
#
#  - Where are the most functional wells located?
#  - Investigating the condition of wells based on construction year and date recorded
#  - What are the most popular water basins?
#  - What is the most popular way of extracting water for the most functional wells?
#  - How is the water quality and quantity for the wells? What are their main source for the water?
#  - Most popular waterpoint types?
#  - Which management was the most popular?

# %% [markdown]
# <b>Where are the most functional wells located?</b>

# %%
fig = plt.figure(figsize=(16,10))
sns.scatterplot(x = df.longitude, y = df.latitude, hue = df.well_condition)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
df = df[df.longitude != 0]

# %%
fig = plt.figure(figsize=(16,10))
sns.scatterplot(x = df.longitude, y = df.latitude, hue = df.well_condition)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
df_date_recorded = df.copy()
df_date_recorded['date_recorded'] = df_date_recorded['date_recorded'].dt.month
df_date_recorded['date_recorded'] = df_date_recorded['date_recorded'].astype(str)
df_date_recorded['date_recorded'].replace({'1': 'Jan', '2': 'Feb', '3': 'Mar', '4': 'Apr', '5': 'May', '6': 'Jun', '7': 'Jul', '8': 'Aug', '9': 'Sept', '10': 'Oct', '11': 'Nov', '12': 'Dec'}, inplace = True)

# %%
df.head()
# Out:
#        id  amount_tsh date_recorded       funder  gps_height installer  \
# 4   19728         0.0    2011-07-13  Action In A           0   Artisan
# 6   19816         0.0    2012-10-01         Dwsp           0      DWSP
# 7   54551         0.0    2012-10-09        Rwssp           0       DWE
# 9   46144         0.0    2011-08-03  Isingiro Ho           0   Artisan
# 14  53752         0.0    2012-10-20        Biore           0    WEDECO
#
#     longitude  latitude      wpt_name            basin  ... scheme_management  \
# 4   31.130847 -1.825359       Shuleni    Lake Victoria  ...         Not Known
# 6   33.362410 -3.766365    Kwa Ngomho         Internal  ...               VWC
# 7   32.620617 -4.226198  Tushirikiane  Lake Tanganyika  ...         Not Known
# 9   30.626991 -1.257051       Kwapeto    Lake Victoria  ...         Not Known
# 14  34.364073 -3.629333     Mwabasabi         Internal  ...               WUG
#
#    permit  construction_year extraction_type payment_type  water_quality  \
# 4    True                  0         gravity    never pay           good
# 6    True                  0          swn 80    never pay           good
# 7    True                  0     nira/tanira      unknown          milky
# 9    True                  0     nira/tanira    never pay           good
# 14   True                  0     nira/tanira    never pay           good
#
#    water_quantity                source     waterpoint_type well_condition
# 4        seasonal  rainwater harvesting  communal standpipe              0
# 6          enough           machine dbh           hand pump              1
# 7          enough          shallow well           hand pump              1
# 9          enough          shallow well           hand pump              0
# 14         enough          shallow well           hand pump              0
#
# [5 rows x 28 columns]

# %% [markdown]
# <b>Investigating the condition of wells based on construction year and date recorded</b>

# %%
well_condition_labels = ['functional', 'non-functional', 'semi-functional']
month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']
ax = df_date_recorded['well_condition'].groupby(by=df_date_recorded['date_recorded']
                       ).value_counts(normalize = True).unstack().plot(kind='bar', 
                                                        stacked=True,
                                                        color=['skyblue', 
                                                                'lightgreen', 
                                                                'pink'], figsize=(10,8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel('Date Recorded', size=14)
plt.ylabel('Frequency (%)', size=14)
plt.xticks(ticks=range(12), labels=month_labels, size=12)
plt.yticks(size=12)
plt.legend(title='Condition of Wells', labels=well_condition_labels, 
           loc='lower right', bbox_to_anchor=(1.2, 0))
plt.show()

# %% [markdown]
# It seems like during the 3 year span, the most amount of functional wells were recorded in the months of March, July and December. The most non-functional wells were recorded in the months of June, Sept, Oct, and Nov. Transforming the months into dummy_variables seems like a option now due to noticeable trends. Before we do that, let's investigate the construction years in relation to the well conditions. I will group by construction years into groups of 5 years.

# %%
df_date_recorded.construction_year.replace(0, np.nan, inplace = True)

# %%
a = list(range(1955,2016,5))
cut_bins = [-1]
cut_bins.extend(a)
cut_labels = ['not available', '56-60','61-65','66-70','71-75','76-80','81-85','86-90','91-95','96-00','01-05','06-10','11-15']
df_date_recorded.loc[:, 'construction_year_bin'] = pd.cut(df_date_recorded['construction_year'], bins = cut_bins, labels = cut_labels)

df_date_recorded.construction_year_bin
# Out:
# 4          NaN
# 6          NaN
# 7          NaN
# 9          NaN
# 14         NaN
#          ...
# 59388    91-95
# 59390    91-95
# 59391    66-70
# 59397      NaN
# 59398      NaN
# Name: construction_year_bin, Length: 25524, dtype: category
# Categories (13, object): ['not available' < '56-60' < '61-65' < '66-70' ... '96-00' < '01-05' < '06-10' < '11-15']

# %%
df_date_recorded.tail()
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 59388  72559         0.0           Jan                   Kidep        1414
# 59390  13677         0.0           Aug                   Rudep        1715
# 59391  44885         0.0           Aug  Government Of Tanzania         540
# 59397  37057         0.0           Apr               Not Known           0
# 59398  31282         0.0           Mar                   Malec           0
#
#         installer  longitude  latitude            wpt_name            basin  \
# 59388         DWE  30.692400 -3.593827  Kwa Philipo Kibeba  Lake Tanganyika
# 59390         DWE  31.370848 -8.258160     Kwa Mzee Atanas  Lake Tanganyika
# 59391  Government  38.044070 -4.272218                 Kwa          Pangani
# 59397   Not Known  34.017087 -8.750434             Mashine           Rufiji
# 59398        Musa  35.861315 -6.378573              Mshoro           Rufiji
#
#        ... permit construction_year  extraction_type payment_type  \
# 59388  ...   True            1995.0          gravity      unknown
# 59390  ...  False            1991.0           swn 80    never pay
# 59391  ...   True            1967.0          gravity    never pay
# 59397  ...  False               NaN           swn 80      monthly
# 59398  ...   True               NaN      nira/tanira    never pay
#
#       water_quality  water_quantity        source     waterpoint_type  \
# 59388          good    insufficient        spring     improved spring
# 59390          good    insufficient   machine dbh           hand pump
# 59391          good          enough         river  communal standpipe
# 59397      fluoride          enough   machine dbh           hand pump
# 59398          good    insufficient  shallow well           hand pump
#
#       well_condition construction_year_bin
# 59388              0                 91-95
# 59390              0                 91-95
# 59391              1                 66-70
# 59397              0                   NaN
# 59398              0                   NaN
#
# [5 rows x 29 columns]

# %%
# Convert year constructed into strings
df_date_recorded['construction_year_bin'] = df_date_recorded['construction_year_bin'].astype(str)

# %%
well_condition_labels = ['functional', 'non-functional', 'semi-functional']
month_labels = ['56-60', '61-65', '66-70', '71-75', '76-80', '81-85', '86-90', '91-95', '96-00', '01-05', '06-10', '11-15', 'Not Known']
ax = df_date_recorded['well_condition'].groupby(by=df_date_recorded['construction_year_bin']
                       ).value_counts(normalize = True).unstack().plot(kind='bar', 
                                                        stacked=True,
                                                        color=['skyblue', 
                                                                'lightgreen', 
                                                                'pink'], figsize=(10,8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel('Year Constructed', size=14)
plt.ylabel('Frequency (%)', size=14)
plt.xticks(ticks=range(13), labels=month_labels, size=12)
plt.yticks(size=12)
plt.legend(title='Condition of Wells', labels=well_condition_labels, 
           loc='lower right', bbox_to_anchor=(1.2, 0))
plt.show()

# %% [markdown]
# There seems to be a trend here, newer constructed wells actually tends to be less functional. Wells constructed during 1955-1970 seemed to be the most functional and wells constructed during 1975 to 2000 seemed to have the most non-functional wells. I will definitely consider binning the construction years and transform them into dummy variables.

# %% [markdown]
# <b>What are the most popular water basins?</b>

# %%
well_condition_labels = ['functional', 'non-functional', 'semi-functional']
basin_labels = ['Lake Victoria', 'Pangani', 'Rufiji', 'Internal', 'Lake Tanganyika']
ax = df['well_condition'].groupby(by=df['basin']
                       ).value_counts(normalize = True).unstack().plot(kind='bar', 
                                                        stacked=True,
                                                        color=['skyblue', 
                                                                'lightgreen', 
                                                                'pink'], figsize=(10,8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel('Most popular water basin areas', size=14)
plt.ylabel('Frequency (%)', size=14)
plt.xticks(ticks=range(5), labels=basin_labels, size=12)
plt.yticks(size=12)
plt.legend(title='Condition of Wells', labels=well_condition_labels, 
           loc='lower right', bbox_to_anchor=(1.2, 0))
plt.show()

# %% [markdown]
# No clear trend here, but Lake Victoria and Lake Tanganyika appear to have the highest number of functioning water wells

# %% [markdown]
# <b>Most popular way of extracting water for the most functional wells?</b>

# %%
well_condition_labels = ['functional', 'non-functional', 'semi-functional']
extraction_labels = ['gravity', 'nira/tanira','other', 'submersible', 'swn 80', 'Not Known', 'Not Known', 'Not Known', 'Not Known']
ax = df['well_condition'].groupby(by=df['extraction_type']
                       ).value_counts(normalize = True).unstack().plot(kind='bar', 
                                                        stacked=True,
                                                        color=['skyblue', 
                                                                'lightgreen', 
                                                                'pink'], figsize=(10,8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel('Top Extraction Methods', size=14)
plt.ylabel('Frequency (%)', size=14)
plt.xticks(ticks=range(9), labels=extraction_labels, size=12)
plt.yticks(size=12)
plt.legend(title='Condition of Wells', labels=well_condition_labels, 
           loc='lower right', bbox_to_anchor=(1.2, 0))
plt.show()

# %% [markdown]
# <b>Best water sources and water quality and water quantity</b>

# %%
well_condition_labels = ['functional', 'non-functional', 'semi-functional']
source_labels = ['spring', 'shallow well', 'machine dbh', 'river', 'rainwater harvesting']    
ax = df_date_recorded['well_condition'].groupby(by=df_date_recorded['source']
                       ).value_counts(normalize = True).unstack().plot(kind='bar', 
                                                        stacked=True,
                                                        color=['skyblue', 
                                                                'lightgreen', 
                                                                'pink'], figsize=(10,8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel('Best Water Sources', size=14)
plt.ylabel('Frequency (%)', size=14)
plt.xticks(ticks=range(5), labels=source_labels, size=12)
plt.yticks(size=12)
plt.legend(title='Condition of Wells', labels=well_condition_labels, 
           loc='lower right', bbox_to_anchor=(1.2, 0))
plt.show()

# %% [markdown]
# Shallow wells appear to be the best water source for functional wells and spring water is the worst

# %%
plt.figure(figsize=(13,10), dpi= 80)
sns.boxplot(x='water_quality', y='gps_height', data=df, hue='well_condition')
sns.stripplot(x='water_quality', y='gps_height', data=df, color='pink', size=3, jitter=1)

for i in range(len(df['water_quantity'].unique())-1):
    plt.vlines(i+.5, 10, 45, linestyles='solid', colors='pink', alpha=0.2)

# Decoration
plt.title('Box Plot of the Altitude of Wells by its Condition and Water quality', fontsize=14)
plt.legend(title='Well Condition')
plt.show()

# %%
well_condition_labels = ['functional', 'non-functional', 'semi-functional']
quality_labels = ['good', 'salty', 'unknown', 'milky', 'colored', 'other']    


ax1 = df_date_recorded['well_condition'].groupby(by=df_date_recorded['water_quality']
                       ).value_counts(normalize = True).unstack().plot(kind='bar', 
                                                        stacked=True,
                                                        color=['skyblue', 
                                                                'lightgreen', 
                                                                'pink'], figsize=(10,8))

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)


plt.xlabel('Best Water Quality', size=14)
plt.ylabel('Frequency (%)', size=14)
plt.xticks(ticks=range(6), labels=quality_labels, size=12)
plt.yticks(size=12)
plt.legend(title='Condition of Wells', labels=well_condition_labels, 
           loc='lower right', bbox_to_anchor=(1.2, 0))
plt.show()

# %% [markdown]
# Although 85% of the water quality is 'good', if you calculate the relative percentage of functional wells to their respective categories, the water quality of 'salty' actually had a better proprionate of functional wells, which could indicate something noteworthy. It is also unfair to conclude that salty quality is better than good quality because there are way more data for the 'good' category. Now let's take a look at the most frequently seen water quantity

# %%
plt.figure(figsize=(13,10), dpi= 80)
sns.boxplot(x='water_quantity', y='gps_height', data=df, hue='well_condition')
sns.stripplot(x='water_quantity', y='gps_height', data=df, color='pink', size=3, jitter=1)

for i in range(len(df['water_quantity'].unique())-1):
    plt.vlines(i+.5, 10, 45, linestyles='solid', colors='pink', alpha=0.2)

# Decoration
plt.title('Box Plot of the Altitude of Wells by its Condition and Water quantity', fontsize=14)
plt.legend(title='Well Condition')
plt.show()

# %% [markdown]
# This is a signficant finding, as I would have assumed that having enough water would possibly correlate to more functioning wells. However, it turns out when the water quantity is insufficient or seasonal, it yields to more functional wells. Now let's take a look at the best types of waterpoint

# %%
well_condition_labels = ['functional', 'non-functional', 'semi-functional']
waterpoint_labels = ['communal standpipe', 'hand pump', 'other', 'communal standpipe multiple','improved spring']
ax = df_date_recorded['well_condition'].groupby(by=df_date_recorded['scheme_management']
                       ).value_counts(normalize = True).unstack().plot(kind='bar', 
                                                        stacked=True,
                                                        color=['skyblue', 
                                                                'lightgreen', 
                                                                'pink'], figsize=(10,8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel('Best waterpoint types', size=14)
plt.ylabel('Frequency (%)', size=14)
plt.xticks(ticks=range(5), labels=waterpoint_labels, size=12)
plt.yticks(size=12)
plt.legend(title='Condition of Wells', labels=well_condition_labels, 
           loc='lower right', bbox_to_anchor=(1.2, 0))
plt.show()

# %% [markdown]
# There seems to be no clear trend, all the waterpoint types appear to produce the same information.

# %% [markdown]
# <b>Top Managements</b>

# %%
well_condition_labels = ['functional', 'non-functional', 'semi-functional']
management_labels = ['VWC', 'WUG', 'Water Authority', 'WUA', 'Not Known']
ax = df_date_recorded['well_condition'].groupby(by=df_date_recorded['scheme_management']
                       ).value_counts(normalize = True).unstack().plot(kind='bar', 
                                                        stacked=True,
                                                        color=['skyblue', 
                                                                'lightgreen', 
                                                                'pink'], figsize=(10,8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel('Top Managements for the Wells', size=14)
plt.ylabel('Frequency (%)', size=14)
plt.xticks(ticks=range(5), labels=management_labels, size=12)
plt.yticks(size=12)
plt.legend(title='Condition of Wells', labels=well_condition_labels, 
           loc='lower right', bbox_to_anchor=(1.2, 0))
plt.show()

# %% [markdown]
# There does not seem to be any clear management advantage trends/patterns. Water authority does appear to have a slight edge over the other ones, as they manage the most functional wells and the least non-functional ones.

# %%
df.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  25524.000000   25524.000000  25524.000000  25524.000000  25524.000000
# mean   37046.945228     186.302092    766.347046     34.501996     -4.605492
# std    21363.357067    2485.650709    701.231571      2.620159      2.268226
# min        1.000000       0.000000    -46.000000     29.607201    -10.631144
# 25%    18697.500000       0.000000      0.000000     32.383617     -5.255884
# 50%    36873.500000       0.000000    832.000000     34.669569     -4.031341
# 75%    55456.500000       5.000000   1407.000000     36.722652     -3.190338
# max    74246.000000  200000.000000   2628.000000     39.878767     -0.998464
#
#         region_code    population  construction_year
# count  25524.000000  25524.000000       25524.000000
# mean      12.535143    180.112169        1286.253683
# std        8.929079    441.876126         955.544540
# min        1.000000      0.000000           0.000000
# 25%        4.000000      0.000000           0.000000
# 50%       14.000000     50.000000        1984.000000
# 75%       18.000000    230.000000        2003.000000
# max       80.000000  30500.000000        2013.000000

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.kdeplot(df.loc[df['well_condition'] == '0', "population"], shade=True, color="deeppink", label="Functional", alpha=.7)
sns.kdeplot(df.loc[df['well_condition'] == '1', "population"], shade=True, color="lightgreen", label="Non Functional", alpha=.7)
sns.kdeplot(df.loc[df['well_condition'] == '2', "population"], shade=True, color="dodgerblue", label="Semi Functional", alpha=.7)

# Decoration
plt.title('Density Plot of Population by well condition', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# Most of the population around the wells tend to be on the smaller side, between 0 to 5000 and with an outlier of around 30500. With that in mind, let's take a look at the top 5 management. We already have a idea from earlier of what the top 5 most frequently seen management values were, and they were: VWC, WUG, Not Known, Water authority, WUA. However, this is not an order, we will now rank to see which management managed the most functional wells.

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.kdeplot(df.loc[df['well_condition'] == '0', "gps_height"], shade=True, color="lightgreen", label="Functional", alpha=.7)
sns.kdeplot(df.loc[df['well_condition'] == '1', "gps_height"], shade=True, color="deeppink", label="Non Functional", alpha=.7)
sns.kdeplot(df.loc[df['well_condition'] == '2', "gps_height"], shade=True, color="dodgerblue", label="Semi Functional", alpha=.7)

# Decoration
plt.title('Density Plot of gps_height by well condition', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# The distribution of the wells appear to follow the same distribution regardless of the well condition, with slight differences. It also appears to be bi-modal distribution, as most of the values tend to appear between -500 and 500 and then between 500 and 2000

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.kdeplot(df.loc[df['well_condition'] == '0', "region_code"], shade=True, color="lightgreen", label="Functional", alpha=.7)
sns.kdeplot(df.loc[df['well_condition'] == '1', "region_code"], shade=True, color="deeppink", label="Non Functional", alpha=.7)
sns.kdeplot(df.loc[df['well_condition'] == '2', "region_code"], shade=True, color="dodgerblue", label="Semi Functional", alpha=.7)

# Decoration
plt.title('Density Plot of region_code by well condition', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# Appears to be bimodal as well. Most codes lie within a region of 0 to 25

# %% [markdown]
# Where are the most recently constructed wells?

# %%
fig = plt.figure(figsize=(25,25))

#ALL sales in set, represents map background
sns.scatterplot(x=df_date_recorded.longitude, y=df_date_recorded.latitude, hue = df_date_recorded['construction_year'])
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# There is no obvious clustering, wells appear to be constructed at the same time throughout the whole map. Construction year might not have an importance, so we can bin the construction years later and see if there are any individual segments that might hold some value.

# %% [markdown]
# Is there a relationship between the altitude of the well and the amount of water available to the waterpoint?

# %%
plt.figure(figsize = (16, 10))
sns.scatterplot(x = df['gps_height'], y = df['amount_tsh'])
# Out:
# <AxesSubplot:xlabel='gps_height', ylabel='amount_tsh'>

# %% [markdown]
# No correlation at all

# %% [markdown]
# How about population and the amount of water available to the waterpoint?

# %%
plt.figure(figsize = (16, 10))
sns.scatterplot(x = df['population'], y = df['amount_tsh'])
# Out:
# <AxesSubplot:xlabel='population', ylabel='amount_tsh'>

# %% [markdown]
# No correlation either

# %% [markdown]
# Summary of EDA section:
#
# Potentially useful features
#   - Date recorded
#   - Construction year
#   - Water sources
#   - Water quantity
#   - Water quality

# %% [markdown]
# <b>Final Data Cleaning Before Model Building</b>

# %%
df_final = df.copy()

# %%
df_final.head()
# Out:
#        id  amount_tsh date_recorded       funder  gps_height installer  \
# 4   19728         0.0    2011-07-13  Action In A           0   Artisan
# 6   19816         0.0    2012-10-01         Dwsp           0      DWSP
# 7   54551         0.0    2012-10-09        Rwssp           0       DWE
# 9   46144         0.0    2011-08-03  Isingiro Ho           0   Artisan
# 14  53752         0.0    2012-10-20        Biore           0    WEDECO
#
#     longitude  latitude      wpt_name            basin  ... scheme_management  \
# 4   31.130847 -1.825359       Shuleni    Lake Victoria  ...         Not Known
# 6   33.362410 -3.766365    Kwa Ngomho         Internal  ...               VWC
# 7   32.620617 -4.226198  Tushirikiane  Lake Tanganyika  ...         Not Known
# 9   30.626991 -1.257051       Kwapeto    Lake Victoria  ...         Not Known
# 14  34.364073 -3.629333     Mwabasabi         Internal  ...               WUG
#
#    permit  construction_year extraction_type payment_type  water_quality  \
# 4    True                  0         gravity    never pay           good
# 6    True                  0          swn 80    never pay           good
# 7    True                  0     nira/tanira      unknown          milky
# 9    True                  0     nira/tanira    never pay           good
# 14   True                  0     nira/tanira    never pay           good
#
#    water_quantity                source     waterpoint_type well_condition
# 4        seasonal  rainwater harvesting  communal standpipe              0
# 6          enough           machine dbh           hand pump              1
# 7          enough          shallow well           hand pump              1
# 9          enough          shallow well           hand pump              0
# 14         enough          shallow well           hand pump              0
#
# [5 rows x 28 columns]

# %%
df_final.drop('id', axis = 1, inplace = True)

# %%
df_final['date_recorded'] = df_final['date_recorded'].dt.month

# %%
df_final.head()
# Out:
#     amount_tsh  date_recorded       funder  gps_height installer  longitude  \
# 4          0.0              7  Action In A           0   Artisan  31.130847
# 6          0.0             10         Dwsp           0      DWSP  33.362410
# 7          0.0             10        Rwssp           0       DWE  32.620617
# 9          0.0              8  Isingiro Ho           0   Artisan  30.626991
# 14         0.0             10        Biore           0    WEDECO  34.364073
#
#     latitude      wpt_name            basin       subvillage  ...  \
# 4  -1.825359       Shuleni    Lake Victoria       Kyanyamisa  ...
# 6  -3.766365    Kwa Ngomho         Internal    Ishinabulandi  ...
# 7  -4.226198  Tushirikiane  Lake Tanganyika  Nyawishi Center  ...
# 9  -1.257051       Kwapeto    Lake Victoria         Mkonomre  ...
# 14 -3.629333     Mwabasabi         Internal        Mwabasabi  ...
#
#    scheme_management  permit construction_year extraction_type  payment_type  \
# 4          Not Known    True                 0         gravity     never pay
# 6                VWC    True                 0          swn 80     never pay
# 7          Not Known    True                 0     nira/tanira       unknown
# 9          Not Known    True                 0     nira/tanira     never pay
# 14               WUG    True                 0     nira/tanira     never pay
#
#    water_quality water_quantity                source     waterpoint_type  \
# 4           good       seasonal  rainwater harvesting  communal standpipe
# 6           good         enough           machine dbh           hand pump
# 7          milky         enough          shallow well           hand pump
# 9           good         enough          shallow well           hand pump
# 14          good         enough          shallow well           hand pump
#
#     well_condition
# 4                0
# 6                1
# 7                1
# 9                0
# 14               0
#
# [5 rows x 27 columns]

# %%
a = list(range(1955,2016,5))
cut_bins = [-1]
cut_bins.extend(a)
cut_labels = ['not available', '56-60','61-65','66-70','71-75','76-80','81-85','86-90','91-95','96-00','01-05','06-10','11-15']
df_final.loc[:, 'construction_year_bin'] = pd.cut(df_final['construction_year'], bins = cut_bins, labels = cut_labels)
df_final.drop('construction_year', axis = 1, inplace = True)

# %%
df_final['construction_year_bin'].replace({'not available': '0', '56-60': '1958', '61-65': '1963', '66-70': '1968', '71-75': '1973', '71-75': '1973', '76-80': '1978', '81-85': '1983', '86-90': '1988', '91-95': '1993', '96-00': '1998', '01-05': '2003', '06-10': '2008', '11-15': '2013'}, inplace = True)
df_final.head()
# Out:
#     amount_tsh  date_recorded       funder  gps_height installer  longitude  \
# 4          0.0              7  Action In A           0   Artisan  31.130847
# 6          0.0             10         Dwsp           0      DWSP  33.362410
# 7          0.0             10        Rwssp           0       DWE  32.620617
# 9          0.0              8  Isingiro Ho           0   Artisan  30.626991
# 14         0.0             10        Biore           0    WEDECO  34.364073
#
#     latitude      wpt_name            basin       subvillage  ...  \
# 4  -1.825359       Shuleni    Lake Victoria       Kyanyamisa  ...
# 6  -3.766365    Kwa Ngomho         Internal    Ishinabulandi  ...
# 7  -4.226198  Tushirikiane  Lake Tanganyika  Nyawishi Center  ...
# 9  -1.257051       Kwapeto    Lake Victoria         Mkonomre  ...
# 14 -3.629333     Mwabasabi         Internal        Mwabasabi  ...
#
#    scheme_management  permit extraction_type payment_type  water_quality  \
# 4          Not Known    True         gravity    never pay           good
# 6                VWC    True          swn 80    never pay           good
# 7          Not Known    True     nira/tanira      unknown          milky
# 9          Not Known    True     nira/tanira    never pay           good
# 14               WUG    True     nira/tanira    never pay           good
#
#    water_quantity                source     waterpoint_type well_condition  \
# 4        seasonal  rainwater harvesting  communal standpipe              0
# 6          enough           machine dbh           hand pump              1
# 7          enough          shallow well           hand pump              1
# 9          enough          shallow well           hand pump              0
# 14         enough          shallow well           hand pump              0
#
#    construction_year_bin
# 4                      0
# 6                      0
# 7                      0
# 9                      0
# 14                     0
#
# [5 rows x 27 columns]

# %%
df_final.tail()
# Out:
#        amount_tsh  date_recorded                  funder  gps_height  \
# 59388         0.0              1                   Kidep        1414
# 59390         0.0              8                   Rudep        1715
# 59391         0.0              8  Government Of Tanzania         540
# 59397         0.0              4               Not Known           0
# 59398         0.0              3                   Malec           0
#
#         installer  longitude  latitude            wpt_name            basin  \
# 59388         DWE  30.692400 -3.593827  Kwa Philipo Kibeba  Lake Tanganyika
# 59390         DWE  31.370848 -8.258160     Kwa Mzee Atanas  Lake Tanganyika
# 59391  Government  38.044070 -4.272218                 Kwa          Pangani
# 59397   Not Known  34.017087 -8.750434             Mashine           Rufiji
# 59398        Musa  35.861315 -6.378573              Mshoro           Rufiji
#
#        subvillage  ... scheme_management  permit extraction_type payment_type  \
# 59388    Kumwambu  ...               VWC    True         gravity      unknown
# 59390     Kitonto  ...               VWC   False          swn 80    never pay
# 59391  Maore Kati  ...   Water authority    True         gravity    never pay
# 59397   Madungulu  ...               VWC   False          swn 80      monthly
# 59398      Mwinyi  ...               VWC    True     nira/tanira    never pay
#
#        water_quality water_quantity        source     waterpoint_type  \
# 59388           good   insufficient        spring     improved spring
# 59390           good   insufficient   machine dbh           hand pump
# 59391           good         enough         river  communal standpipe
# 59397       fluoride         enough   machine dbh           hand pump
# 59398           good   insufficient  shallow well           hand pump
#
#       well_condition construction_year_bin
# 59388              0                  1993
# 59390              0                  1993
# 59391              1                  1968
# 59397              0                     0
# 59398              0                     0
#
# [5 rows x 27 columns]

# %%
df_final.head()
# Out:
#     amount_tsh  date_recorded       funder  gps_height installer  longitude  \
# 4          0.0              7  Action In A           0   Artisan  31.130847
# 6          0.0             10         Dwsp           0      DWSP  33.362410
# 7          0.0             10        Rwssp           0       DWE  32.620617
# 9          0.0              8  Isingiro Ho           0   Artisan  30.626991
# 14         0.0             10        Biore           0    WEDECO  34.364073
#
#     latitude      wpt_name            basin       subvillage  ...  \
# 4  -1.825359       Shuleni    Lake Victoria       Kyanyamisa  ...
# 6  -3.766365    Kwa Ngomho         Internal    Ishinabulandi  ...
# 7  -4.226198  Tushirikiane  Lake Tanganyika  Nyawishi Center  ...
# 9  -1.257051       Kwapeto    Lake Victoria         Mkonomre  ...
# 14 -3.629333     Mwabasabi         Internal        Mwabasabi  ...
#
#    scheme_management  permit extraction_type payment_type  water_quality  \
# 4          Not Known    True         gravity    never pay           good
# 6                VWC    True          swn 80    never pay           good
# 7          Not Known    True     nira/tanira      unknown          milky
# 9          Not Known    True     nira/tanira    never pay           good
# 14               WUG    True     nira/tanira    never pay           good
#
#    water_quantity                source     waterpoint_type well_condition  \
# 4        seasonal  rainwater harvesting  communal standpipe              0
# 6          enough           machine dbh           hand pump              1
# 7          enough          shallow well           hand pump              1
# 9          enough          shallow well           hand pump              0
# 14         enough          shallow well           hand pump              0
#
#    construction_year_bin
# 4                      0
# 6                      0
# 7                      0
# 9                      0
# 14                     0
#
# [5 rows x 27 columns]

# %%
df_final.describe()
# Out:
#           amount_tsh  date_recorded    gps_height     longitude      latitude  \
# count   25524.000000   25524.000000  25524.000000  25524.000000  25524.000000
# mean      186.302092       4.696795    766.347046     34.501996     -4.605492
# std      2485.650709       3.100875    701.231571      2.620159      2.268226
# min         0.000000       1.000000    -46.000000     29.607201    -10.631144
# 25%         0.000000       2.000000      0.000000     32.383617     -5.255884
# 50%         0.000000       3.000000    832.000000     34.669569     -4.031341
# 75%         5.000000       7.000000   1407.000000     36.722652     -3.190338
# max    200000.000000      12.000000   2628.000000     39.878767     -0.998464
#
#         region_code    population
# count  25524.000000  25524.000000
# mean      12.535143    180.112169
# std        8.929079    441.876126
# min        1.000000      0.000000
# 25%        4.000000      0.000000
# 50%       14.000000     50.000000
# 75%       18.000000    230.000000
# max       80.000000  30500.000000

# %%
filtered_drop = df_final.loc[(df_final['amount_tsh'] > 5000) | (df_final['gps_height'] > 2000) | (df_final['region_code'] > 50) 
                             | (df_final['population'] > 500)].index
df_final.drop(filtered_drop, inplace = True)

# %%
df_final.describe()
# Out:
#          amount_tsh  date_recorded    gps_height     longitude      latitude  \
# count  22963.000000   22963.000000  22963.000000  22963.000000  22963.000000
# mean      86.716614       4.884641    727.446632     34.475390     -4.496606
# std      286.834623       3.122624    694.810589      2.554878      2.222711
# min        0.000000       1.000000    -40.000000     29.611947    -10.631144
# 25%        0.000000       3.000000      0.000000     32.393320     -5.078363
# 50%        0.000000       3.000000    723.000000     34.628204     -3.838316
# 75%        0.000000       7.000000   1387.000000     36.721877     -3.149526
# max     5000.000000      12.000000   2000.000000     39.878767     -0.998464
#
#         region_code    population
# count  22963.000000  22963.000000
# mean      11.836084    103.552585
# std        6.785492    136.021204
# min        1.000000      0.000000
# 25%        4.000000      0.000000
# 50%       14.000000     20.000000
# 75%       18.000000    200.000000
# max       24.000000    500.000000

# %% [markdown]
# Now let's perform some more filtering for the other features that we have not touched upon, including:
#  - wpt_name
#  - subvillage
#  - region
#  - installer

# %% [markdown]
# We need to clean wpt_name and subvillage immensely, as there are too many different data values. Region and installer are okay.

# %%
df_final['wpt_name'].value_counts()
# Out:
# none                  793
# Shuleni               434
# Zahanati              279
# Msikitini             157
# Shule Ya Msingi       125
#                      ...
# Kwa Mzee Nyamsha        1
# Kwa Essau Mfikwa        1
# Lugandu                 1
# Kwa Joshua Emanuel      1
# Kwa Janesi              1
# Name: wpt_name, Length: 15903, dtype: int64

# %%
threshold = 365
cols = ['wpt_name']

for col in cols:
    valued_dict = dict(df_final[col].value_counts())
    safe_values = list(key for key, value in valued_dict.items() if value > threshold)
#     replace_values = list(filter(lambda x: x not in safe_values, all_values))
    df_final.loc[:, col] = df_final.loc[:, col].map(lambda y: 'other' if y not in safe_values else y)

df_final.wpt_name.value_counts()
# Out:
# other      21736
# none         793
# Shuleni      434
# Name: wpt_name, dtype: int64

# %%
df_final['subvillage'].value_counts()
# Out:
# Madukani    195
# Kati        194
# Majengo     159
# Shuleni     129
# Mtakuja     109
#            ...
# Kumabuye      1
# Mahanga       1
# Ng'Esha       1
# Dokambwa      1
# Mgaja         1
# Name: subvillage, Length: 9417, dtype: int64

# %%
threshold = 175
cols = ['subvillage']

for col in cols:
    valued_dict = dict(df_final[col].value_counts())
    safe_values = list(key for key, value in valued_dict.items() if value > threshold)
#     replace_values = list(filter(lambda x: x not in safe_values, all_values))
    df_final.loc[:, col] = df_final.loc[:, col].map(lambda y: 'other' if y not in safe_values else y)

df_final.subvillage.value_counts()
# Out:
# other       22574
# Madukani      195
# Kati          194
# Name: subvillage, dtype: int64

# %%
df_final['region'].value_counts()
# Out:
# Kagera         2803
# Shinyanga      2658
# Arusha         2548
# Iringa         1854
# Kilimanjaro    1830
# Tanga          1754
# Kigoma         1598
# Mwanza         1540
# Morogoro       1211
# Manyara         990
# Tabora          861
# Singida         850
# Dodoma          610
# Mara            567
# Mbeya           554
# Rukwa           478
# Ruvuma          178
# Pwani            79
# Name: region, dtype: int64

# %%
threshold = 2020
cols = ['region']

for col in cols:
    valued_dict = dict(df_final[col].value_counts())
    safe_values = list(key for key, value in valued_dict.items() if value > threshold)
#     replace_values = list(filter(lambda x: x not in safe_values, all_values))
    df_final.loc[:, col] = df_final.loc[:, col].map(lambda y: 'other' if y not in safe_values else y)

df_final.region.value_counts()
# Out:
# other        14954
# Kagera        2803
# Shinyanga     2658
# Arusha        2548
# Name: region, dtype: int64

# %%
df_final['installer'].value_counts()
# Out:
# DWE                 9281
# Not Known           1271
# RWE                  612
# Hesawa               555
# Government           487
#                     ...
# KOYI                   1
# lion's club            1
# VICFISH LTD            1
# KKKT Ndrumangeni       1
# Nyabweta               1
# Name: installer, Length: 890, dtype: int64

# %%
threshold = 820
cols = ['installer']

for col in cols:
    valued_dict = dict(df_final[col].value_counts())
    safe_values = list(key for key, value in valued_dict.items() if value > threshold)
#     replace_values = list(filter(lambda x: x not in safe_values, all_values))
    df_final.loc[:, col] = df_final.loc[:, col].map(lambda y: 'other' if y not in safe_values else y)

df_final.installer.value_counts()
# Out:
# other        12411
# DWE           9281
# Not Known     1271
# Name: installer, dtype: int64

# %%
clean_columns = ['wpt_name', 'subvillage', 'region', 'installer']
for col in clean_columns:
    print('The Percentage of the top 5 most frequently seen values in {} are: '.format(col))
    print(df_final[col].value_counts(normalize = True).head(5).sum() * 100)
    print('-' * 100)
# Out:
# The Percentage of the top 5 most frequently seen values in wpt_name are:
# 100.0
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in subvillage are:
# 100.0
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in region are:
# 100.0
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in installer are:
# 99.99999999999999
# ----------------------------------------------------------------------------------------------------

# %%
clean_columns = ['wpt_name', 'subvillage', 'region', 'installer']
for col in clean_columns:
    print('The Percentage of the top 5 most frequently seen values in {} are: '.format(col))
    print(df_final[col].value_counts().head(5))
    print('-' * 100)
# Out:
# The Percentage of the top 5 most frequently seen values in wpt_name are:
# other      21736
# none         793
# Shuleni      434
# Name: wpt_name, dtype: int64
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in subvillage are:
# other       22574
# Madukani      195
# Kati          194
# Name: subvillage, dtype: int64
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in region are:
# other        14954
# Kagera        2803
# Shinyanga     2658
# Arusha        2548
# Name: region, dtype: int64
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in installer are:
# other        12411
# DWE           9281
# Not Known     1271
# Name: installer, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
wpt_dummies = pd.get_dummies(df_final['wpt_name'], prefix = 'wpt')
subvill_dummies = pd.get_dummies(df_final['subvillage'], prefix = 'subvill')
reg_dummies = pd.get_dummies(df_final['region'], prefix = 'reg')
installer_dummies = pd.get_dummies(df_final['installer'], prefix = 'inst')

df_final.drop(["wpt_name","subvillage","region", 'installer'], axis=1, inplace = True)

df_final = pd.concat([df_final, wpt_dummies, subvill_dummies, reg_dummies, installer_dummies], axis = 1)

# %%
filtered_water_quality_source = df_final.loc[(~df_final['water_quality'].str.contains('good')) & (~df_final['water_quality'].str.contains('salty')) 
         & (~df_final['water_quality'].str.contains('unknown')) & (~df_final['water_quality'].str.contains('milky')) 
         & (~df_final['water_quality'].str.contains('colored'))].index
df_final.drop(filtered_water_quality_source, inplace = True)
df_final.head()
# Out:
#     amount_tsh  date_recorded       funder  gps_height  longitude  latitude  \
# 4          0.0              7  Action In A           0  31.130847 -1.825359
# 6          0.0             10         Dwsp           0  33.362410 -3.766365
# 7          0.0             10        Rwssp           0  32.620617 -4.226198
# 9          0.0              8  Isingiro Ho           0  30.626991 -1.257051
# 14         0.0             10        Biore           0  34.364073 -3.629333
#
#               basin  region_code              lga        ward  ...  \
# 4     Lake Victoria           18          Karagwe  Nyakasimbi  ...
# 6          Internal           17  Shinyanga Rural      Samuye  ...
# 7   Lake Tanganyika           17           Kahama      Chambo  ...
# 9     Lake Victoria           18          Karagwe      Kaisho  ...
# 14         Internal           17            Meatu       Nkoma  ...
#
#     subvill_Kati subvill_Madukani subvill_other reg_Arusha reg_Kagera  \
# 4              0                0             1          0          1
# 6              0                0             1          0          0
# 7              0                0             1          0          0
# 9              0                0             1          0          1
# 14             0                0             1          0          0
#
#    reg_Shinyanga reg_other inst_DWE inst_Not Known inst_other
# 4              0         0        0              0          1
# 6              1         0        0              0          1
# 7              1         0        1              0          0
# 9              0         0        0              0          1
# 14             1         0        0              0          1
#
# [5 rows x 36 columns]

# %%
clean_columns = ['water_quality', 'water_quantity', 'basin', 'source']
for col in clean_columns:
    print('The Percentage of the top 5 most frequently seen values in {} are: '.format(col))
    print(df_final[col].value_counts(normalize = True).head(5).sum() * 100)
    print('-' * 100)
# Out:
# The Percentage of the top 5 most frequently seen values in water_quality are:
# 100.00000000000003
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in water_quantity are:
# 99.99999999999999
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in basin are:
# 100.0
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in source are:
# 100.0
# ----------------------------------------------------------------------------------------------------

# %%
clean_columns = ['water_quality', 'water_quantity', 'basin', 'source']
for col in clean_columns:
    print('The Percentage of the top 5 most frequently seen values in {} are: '.format(col))
    print(df_final[col].value_counts().head(5))
    print('-' * 100)
# Out:
# The Percentage of the top 5 most frequently seen values in water_quality are:
# good       20123
# salty       1202
# unknown      687
# milky        626
# colored      188
# Name: water_quality, dtype: int64
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in water_quantity are:
# enough          11923
# insufficient     7063
# dry              1841
# seasonal         1662
# unknown           337
# Name: water_quantity, dtype: int64
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in basin are:
# Lake Victoria      5462
# Pangani            5454
# Rufiji             4093
# Internal           3921
# Lake Tanganyika    3896
# Name: basin, dtype: int64
# ----------------------------------------------------------------------------------------------------
# The Percentage of the top 5 most frequently seen values in source are:
# shallow well            8084
# spring                  7818
# river                   3871
# machine dbh             2114
# rainwater harvesting     939
# Name: source, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
water_qual_dummies = pd.get_dummies(df_final['water_quality'], prefix = 'wat_qual')
water_quant_dummies = pd.get_dummies(df_final['water_quantity'], prefix = 'wat_quant')
basin_dummies = pd.get_dummies(df_final['basin'], prefix = 'bas')
source_dummies = pd.get_dummies(df_final['source'], prefix = 'src')

df_final.drop(["water_quality","water_quantity","basin", 'source'], axis=1, inplace = True)

df_final = pd.concat([df_final, water_qual_dummies, water_quant_dummies, basin_dummies, source_dummies], axis = 1)

# %%
date_dummies = pd.get_dummies(df_final['date_recorded'], prefix = 'date')
constr_year_dummies = pd.get_dummies(df_final['construction_year_bin'], prefix = 'constr_yr')
df_final.drop(["date_recorded","construction_year_bin"], axis=1, inplace = True)

df_final = pd.concat([df_final, date_dummies, constr_year_dummies], axis = 1)

# %%
df_final['well_condition'] = pd.to_numeric(df_final['well_condition'])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22826 entries, 4 to 59398
# Data columns (total 75 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   amount_tsh                22826 non-null  float64
#  1   funder                    22826 non-null  object
#  2   gps_height                22826 non-null  int64
#  3   longitude                 22826 non-null  float64
#  4   latitude                  22826 non-null  float64
#  5   region_code               22826 non-null  int64
#  6   lga                       22826 non-null  object
#  7   ward                      22826 non-null  object
#  8   population                22826 non-null  int64
#  9   public_meeting            22826 non-null  object
#  10  recorded_by               22826 non-null  object
#  11  scheme_management         22826 non-null  object
#  12  permit                    22826 non-null  object
#  13  extraction_type           22826 non-null  object
#  14  payment_type              22826 non-null  object
#  15  waterpoint_type           22826 non-null  object
#  16  well_condition            22826 non-null  int64
#  17  wpt_Shuleni               22826 non-null  uint8
#  18  wpt_none                  22826 non-null  uint8
#  19  wpt_other                 22826 non-null  uint8
#  20  subvill_Kati              22826 non-null  uint8
#  21  subvill_Madukani          22826 non-null  uint8
#  22  subvill_other             22826 non-null  uint8
#  23  reg_Arusha                22826 non-null  uint8
#  24  reg_Kagera                22826 non-null  uint8
#  25  reg_Shinyanga             22826 non-null  uint8
#  26  reg_other                 22826 non-null  uint8
#  27  inst_DWE                  22826 non-null  uint8
#  28  inst_Not Known            22826 non-null  uint8
#  29  inst_other                22826 non-null  uint8
#  30  wat_qual_colored          22826 non-null  uint8
#  31  wat_qual_good             22826 non-null  uint8
#  32  wat_qual_milky            22826 non-null  uint8
#  33  wat_qual_salty            22826 non-null  uint8
#  34  wat_qual_unknown          22826 non-null  uint8
#  35  wat_quant_dry             22826 non-null  uint8
#  36  wat_quant_enough          22826 non-null  uint8
#  37  wat_quant_insufficient    22826 non-null  uint8
#  38  wat_quant_seasonal        22826 non-null  uint8
#  39  wat_quant_unknown         22826 non-null  uint8
#  40  bas_Internal              22826 non-null  uint8
#  41  bas_Lake Tanganyika       22826 non-null  uint8
#  42  bas_Lake Victoria         22826 non-null  uint8
#  43  bas_Pangani               22826 non-null  uint8
#  44  bas_Rufiji                22826 non-null  uint8
#  45  src_machine dbh           22826 non-null  uint8
#  46  src_rainwater harvesting  22826 non-null  uint8
#  47  src_river                 22826 non-null  uint8
#  48  src_shallow well          22826 non-null  uint8
#  49  src_spring                22826 non-null  uint8
#  50  date_1                    22826 non-null  uint8
#  51  date_2                    22826 non-null  uint8
#  52  date_3                    22826 non-null  uint8
#  53  date_4                    22826 non-null  uint8
#  54  date_5                    22826 non-null  uint8
#  55  date_6                    22826 non-null  uint8
#  56  date_7                    22826 non-null  uint8
#  57  date_8                    22826 non-null  uint8
#  58  date_9                    22826 non-null  uint8
#  59  date_10                   22826 non-null  uint8
#  60  date_11                   22826 non-null  uint8
#  61  date_12                   22826 non-null  uint8
#  62  constr_yr_0               22826 non-null  uint8
#  63  constr_yr_1958            22826 non-null  uint8
#  64  constr_yr_1963            22826 non-null  uint8
#  65  constr_yr_1968            22826 non-null  uint8
#  66  constr_yr_1973            22826 non-null  uint8
#  67  constr_yr_1978            22826 non-null  uint8
#  68  constr_yr_1983            22826 non-null  uint8
#  69  constr_yr_1988            22826 non-null  uint8
#  70  constr_yr_1993            22826 non-null  uint8
#  71  constr_yr_1998            22826 non-null  uint8
#  72  constr_yr_2003            22826 non-null  uint8
#  73  constr_yr_2008            22826 non-null  uint8
#  74  constr_yr_2013            22826 non-null  uint8
# dtypes: float64(3), int64(4), object(10), uint8(58)
# memory usage: 4.4+ MB

# %%
df_final
# Out:
#        amount_tsh                  funder  gps_height  longitude  latitude  \
# 4             0.0             Action In A           0  31.130847 -1.825359
# 6             0.0                    Dwsp           0  33.362410 -3.766365
# 7             0.0                   Rwssp           0  32.620617 -4.226198
# 9             0.0             Isingiro Ho           0  30.626991 -1.257051
# 14            0.0                   Biore           0  34.364073 -3.629333
# ...           ...                     ...         ...        ...       ...
# 59384         0.0                 Concern           0  30.667805 -2.483710
# 59388         0.0                   Kidep        1414  30.692400 -3.593827
# 59390         0.0                   Rudep        1715  31.370848 -8.258160
# 59391         0.0  Government Of Tanzania         540  38.044070 -4.272218
# 59398         0.0                   Malec           0  35.861315 -6.378573
#
#        region_code               lga           ward  population  \
# 4               18           Karagwe     Nyakasimbi           0
# 6               17   Shinyanga Rural         Samuye           0
# 7               17            Kahama         Chambo           0
# 9               18           Karagwe         Kaisho           0
# 14              17             Meatu          Nkoma           0
# ...            ...               ...            ...         ...
# 59384           18             Ngara      Nyamiyaga           0
# 59388           16           Kibondo  Kibondo Urban         500
# 59390           15  Sumbawanga Rural          Mkowe         150
# 59391            3              Same          Maore         210
# 59398            1          Chamwino   Mvumi Makulu           0
#
#       public_meeting  ... constr_yr_1968 constr_yr_1973 constr_yr_1978  \
# 4               True  ...              0              0              0
# 6               True  ...              0              0              0
# 7               True  ...              0              0              0
# 9               True  ...              0              0              0
# 14              True  ...              0              0              0
# ...              ...  ...            ...            ...            ...
# 59384           True  ...              0              0              0
# 59388           True  ...              0              0              0
# 59390           True  ...              0              0              0
# 59391           True  ...              1              0              0
# 59398           True  ...              0              0              0
#
#       constr_yr_1983 constr_yr_1988 constr_yr_1993  constr_yr_1998  \
# 4                  0              0              0               0
# 6                  0              0              0               0
# 7                  0              0              0               0
# 9                  0              0              0               0
# 14                 0              0              0               0
# ...              ...            ...            ...             ...
# 59384              0              0              0               0
# 59388              0              0              1               0
# 59390              0              0              1               0
# 59391              0              0              0               0
# 59398              0              0              0               0
#
#        constr_yr_2003  constr_yr_2008  constr_yr_2013
# 4                   0               0               0
# 6                   0               0               0
# 7                   0               0               0
# 9                   0               0               0
# 14                  0               0               0
# ...               ...             ...             ...
# 59384               0               0               0
# 59388               0               0               0
# 59390               0               0               0
# 59391               0               0               0
# 59398               0               0               0
#
# [22826 rows x 75 columns]

# %%
df_test = df_final.copy()
df_test = df_final.select_dtypes(exclude=['object'])
df_test.head()
# Out:
#     amount_tsh  gps_height  longitude  latitude  region_code  population  \
# 4          0.0           0  31.130847 -1.825359           18           0
# 6          0.0           0  33.362410 -3.766365           17           0
# 7          0.0           0  32.620617 -4.226198           17           0
# 9          0.0           0  30.626991 -1.257051           18           0
# 14         0.0           0  34.364073 -3.629333           17           0
#
#     well_condition  wpt_Shuleni  wpt_none  wpt_other  ...  constr_yr_1968  \
# 4                0            1         0          0  ...               0
# 6                1            0         0          1  ...               0
# 7                1            0         0          1  ...               0
# 9                0            0         0          1  ...               0
# 14               0            0         0          1  ...               0
#
#     constr_yr_1973  constr_yr_1978  constr_yr_1983  constr_yr_1988  \
# 4                0               0               0               0
# 6                0               0               0               0
# 7                0               0               0               0
# 9                0               0               0               0
# 14               0               0               0               0
#
#     constr_yr_1993  constr_yr_1998  constr_yr_2003  constr_yr_2008  \
# 4                0               0               0               0
# 6                0               0               0               0
# 7                0               0               0               0
# 9                0               0               0               0
# 14               0               0               0               0
#
#     constr_yr_2013
# 4                0
# 6                0
# 7                0
# 9                0
# 14               0
#
# [5 rows x 65 columns]

# %%
df_test_1 = df_test[['amount_tsh', 'gps_height', 'longitude', 'latitude', 'reg_other', 'inst_other', 'wat_qual_salty', 'wat_quant_dry', 'wat_quant_enough', 'wat_quant_insufficient', 'date_7', 'date_8', 'constr_yr_1978', 'constr_yr_2008']]

# %%
df_test_2 = df_test_1[['amount_tsh', 'gps_height', 'longitude', 'latitude', 'reg_other', 'wat_qual_salty', 'wat_quant_dry', 'wat_quant_enough', 'date_7', 'date_8', 'constr_yr_2008']]

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(abs(df_final.corr())> 0.70, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
df_pairs = df_final.corr().abs().stack().reset_index().sort_values(0, ascending = False)
df_pairs['pairs'] = list(zip(df_pairs.level_0, df_pairs.level_1))
df_pairs.set_index(['pairs'], inplace = True)
df_pairs.drop(columns = ['level_1', 'level_0'], inplace = True)
df_pairs.columns = ['correlation']
df_pairs.drop_duplicates(inplace = True)

# %%
df_pairs[(df_pairs.correlation >.70) & (df_pairs.correlation <1)]
# Out:
#                                    correlation
# pairs
# (inst_other, inst_DWE)                0.893422
# (latitude, bas_Rufiji)                0.846774
# (constr_yr_0, gps_height)             0.806194
# (wpt_none, wpt_other)                 0.796996
# (region_code, longitude)              0.750553
# (reg_Kagera, date_7)                  0.733630
# (subvill_other, subvill_Madukani)     0.707825
# (subvill_Kati, subvill_other)         0.700390

# %%
df_final.drop(['wpt_none', 'bas_Pangani', 'inst_DWE'], axis = 1, inplace = True)

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(abs(df_final.corr())> 0.70, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
df_final.drop(['subvill_Madukani', 'wat_quant_dry', 'reg_Kagera', 'constr_yr_0', 'bas_Rufiji', 'wat_quant_enough'], axis = 1, inplace = True)

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(abs(df_final.corr())> 0.70, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
df_final.drop(['subvill_other', 'region_code'], axis = 1, inplace = True)

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(abs(df_final.corr())> 0.70, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
# Final Cleaned Data
df_final.head()
# Out:
#     amount_tsh       funder  gps_height  longitude  latitude              lga  \
# 4          0.0  Action In A           0  31.130847 -1.825359          Karagwe
# 6          0.0         Dwsp           0  33.362410 -3.766365  Shinyanga Rural
# 7          0.0        Rwssp           0  32.620617 -4.226198           Kahama
# 9          0.0  Isingiro Ho           0  30.626991 -1.257051          Karagwe
# 14         0.0        Biore           0  34.364073 -3.629333            Meatu
#
#           ward  population public_meeting              recorded_by  ...  \
# 4   Nyakasimbi           0           True  GeoData Consultants Ltd  ...
# 6       Samuye           0           True  GeoData Consultants Ltd  ...
# 7       Chambo           0           True  GeoData Consultants Ltd  ...
# 9       Kaisho           0           True  GeoData Consultants Ltd  ...
# 14       Nkoma           0           True  GeoData Consultants Ltd  ...
#
#    constr_yr_1968 constr_yr_1973 constr_yr_1978 constr_yr_1983 constr_yr_1988  \
# 4               0              0              0              0              0
# 6               0              0              0              0              0
# 7               0              0              0              0              0
# 9               0              0              0              0              0
# 14              0              0              0              0              0
#
#     constr_yr_1993  constr_yr_1998  constr_yr_2003  constr_yr_2008  \
# 4                0               0               0               0
# 6                0               0               0               0
# 7                0               0               0               0
# 9                0               0               0               0
# 14               0               0               0               0
#
#     constr_yr_2013
# 4                0
# 6                0
# 7                0
# 9                0
# 14               0
#
# [5 rows x 64 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22826 entries, 4 to 59398
# Data columns (total 64 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   amount_tsh                22826 non-null  float64
#  1   funder                    22826 non-null  object
#  2   gps_height                22826 non-null  int64
#  3   longitude                 22826 non-null  float64
#  4   latitude                  22826 non-null  float64
#  5   lga                       22826 non-null  object
#  6   ward                      22826 non-null  object
#  7   population                22826 non-null  int64
#  8   public_meeting            22826 non-null  object
#  9   recorded_by               22826 non-null  object
#  10  scheme_management         22826 non-null  object
#  11  permit                    22826 non-null  object
#  12  extraction_type           22826 non-null  object
#  13  payment_type              22826 non-null  object
#  14  waterpoint_type           22826 non-null  object
#  15  well_condition            22826 non-null  int64
#  16  wpt_Shuleni               22826 non-null  uint8
#  17  wpt_other                 22826 non-null  uint8
#  18  subvill_Kati              22826 non-null  uint8
#  19  reg_Arusha                22826 non-null  uint8
#  20  reg_Shinyanga             22826 non-null  uint8
#  21  reg_other                 22826 non-null  uint8
#  22  inst_Not Known            22826 non-null  uint8
#  23  inst_other                22826 non-null  uint8
#  24  wat_qual_colored          22826 non-null  uint8
#  25  wat_qual_good             22826 non-null  uint8
#  26  wat_qual_milky            22826 non-null  uint8
#  27  wat_qual_salty            22826 non-null  uint8
#  28  wat_qual_unknown          22826 non-null  uint8
#  29  wat_quant_insufficient    22826 non-null  uint8
#  30  wat_quant_seasonal        22826 non-null  uint8
#  31  wat_quant_unknown         22826 non-null  uint8
#  32  bas_Internal              22826 non-null  uint8
#  33  bas_Lake Tanganyika       22826 non-null  uint8
#  34  bas_Lake Victoria         22826 non-null  uint8
#  35  src_machine dbh           22826 non-null  uint8
#  36  src_rainwater harvesting  22826 non-null  uint8
#  37  src_river                 22826 non-null  uint8
#  38  src_shallow well          22826 non-null  uint8
#  39  src_spring                22826 non-null  uint8
#  40  date_1                    22826 non-null  uint8
#  41  date_2                    22826 non-null  uint8
#  42  date_3                    22826 non-null  uint8
#  43  date_4                    22826 non-null  uint8
#  44  date_5                    22826 non-null  uint8
#  45  date_6                    22826 non-null  uint8
#  46  date_7                    22826 non-null  uint8
#  47  date_8                    22826 non-null  uint8
#  48  date_9                    22826 non-null  uint8
#  49  date_10                   22826 non-null  uint8
#  50  date_11                   22826 non-null  uint8
#  51  date_12                   22826 non-null  uint8
#  52  constr_yr_1958            22826 non-null  uint8
#  53  constr_yr_1963            22826 non-null  uint8
#  54  constr_yr_1968            22826 non-null  uint8
#  55  constr_yr_1973            22826 non-null  uint8
#  56  constr_yr_1978            22826 non-null  uint8
#  57  constr_yr_1983            22826 non-null  uint8
#  58  constr_yr_1988            22826 non-null  uint8
#  59  constr_yr_1993            22826 non-null  uint8
#  60  constr_yr_1998            22826 non-null  uint8
#  61  constr_yr_2003            22826 non-null  uint8
#  62  constr_yr_2008            22826 non-null  uint8
#  63  constr_yr_2013            22826 non-null  uint8
# dtypes: float64(3), int64(3), object(10), uint8(48)
# memory usage: 4.0+ MB

# %% [markdown]
# # Model Building

# %% [markdown]
# We will start by selecting the features that were important in the Boruta algorithm. After much experimenting, I arrived with the conclusion of inputting these 12 features into my model before any hyperparameter tuning.

# %%
df_features = df_final[['amount_tsh', 'gps_height', 'longitude', 'latitude', 'wat_qual_salty', 'date_7', 'date_8', 'constr_yr_2008', 
                        'population', 'src_shallow well', 'wat_quant_insufficient', 'src_machine dbh']]

# %%
df_features.head()
# Out:
#     amount_tsh  gps_height  longitude  latitude  wat_qual_salty  date_7  \
# 4          0.0           0  31.130847 -1.825359               0       1
# 6          0.0           0  33.362410 -3.766365               0       0
# 7          0.0           0  32.620617 -4.226198               0       0
# 9          0.0           0  30.626991 -1.257051               0       0
# 14         0.0           0  34.364073 -3.629333               0       0
#
#     date_8  constr_yr_2008  population  src_shallow well  \
# 4        0               0           0                 0
# 6        0               0           0                 0
# 7        0               0           0                 1
# 9        1               0           0                 1
# 14       0               0           0                 1
#
#     wat_quant_insufficient  src_machine dbh
# 4                        0                0
# 6                        0                1
# 7                        0                0
# 9                        0                0
# 14                       0                0

# %%
target = df_final['well_condition']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_features, target, test_size = 0.2, random_state = 123)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Before we head into the model building experimenting, let's create some helpful functions to assist in the process

# %%
def print_metrics(labels, preds):
    print('Precision Score: {}'.format(precision_score(labels, preds, average = None)))
    print("Recall Score: {}".format(recall_score(labels, preds, average=None)))
    print("Accuracy Score: {}".format(accuracy_score(labels, preds)))
    print("F1 Score: {}".format(f1_score(labels, preds, average=None)))

# %%
def plot_cm(target, labels, name, target_classes=3):
    '''
    Args:
       target : True labels of the target variable 
       labels : Predicted labels of the target variable
       name : String; Name of the model to be specified as the title of the plot
       target_classes : Number of classes in the target variable 
    
    Returns:
        Plots confusion metrix.
        
    '''
    cm = confusion_matrix(target, labels) 
    
    # Transform to df for easier plotting
    if target_classes == 3:
        cm_df = pd.DataFrame(cm,
                             index = ['Functional','Non-Functional','Semi-Functional'], 
                             columns = ['Functional','Non-Functional','Semi-Functional'])
    else:
        cm_df = pd.DataFrame(cm,
                 index = ['Functional','Non-Functional','Semi-Functional'], 
                 columns = ['Functional','Non-Functional','Semi-Functional'])
        
    sns.heatmap(cm_df, annot=True, cmap='GnBu', vmax=60, annot_kws={"size": 14}, fmt='.3g')
    plt.title('{} \nAccuracy:{} \nWeighted F1 Score:{}'.format(name, 
                                        np.round(accuracy_score(target, labels),3),
                                        np.round(f1_score(target, labels, average='weighted'),3)),
               
             size=17)
    
    plt.ylabel('True label', size=15)
    plt.yticks(rotation=30) 
    plt.xlabel('Predicted label', size=15)

# %%
def plot_feature_importances(df, model, num):
    '''
    Args:
       df : Underlying datafarame of the model 
       model : Model to extract feature importances from
       num : Number of features to plot
    
    Returns:
        Plots a bar graph of feature importances of n features, in 
        in descending order of feature importances
    '''

    feat_importances = pd.Series(model.feature_importances_, index=df.columns)
    feat_importances.nlargest(num).plot(kind='barh', color =['skyblue', 'pink', 'lightgreen'])

# %%
pipeline_names = ['Decision Tree','Random Forest', 'Adaboost', 'Gradient Boosting', 'LogisticRegression']

# %%
pipe_tree = Pipeline([('clf', DecisionTreeClassifier(random_state=123))])
pipe_forest = Pipeline([('clf', RandomForestClassifier(random_state=123))])
pipe_adaboost = Pipeline([('clf', AdaBoostClassifier(random_state=123))])
pipe_gbt = Pipeline([('clf', GradientBoostingClassifier(random_state=123))])
pipe_log = Pipeline([('clf', LogisticRegression(random_state=123))])

# List of pipelines, List of pipeline names
pipelines = [pipe_tree, pipe_forest, pipe_adaboost, pipe_gbt, pipe_log]

for pipe in pipelines:
    print(pipe)
    pipe.fit(X_train_scaled, y_train)
# Out:
# Pipeline(steps=[('clf', DecisionTreeClassifier(random_state=123))])
# Pipeline(steps=[('clf', RandomForestClassifier(random_state=123))])
# Pipeline(steps=[('clf', AdaBoostClassifier(random_state=123))])
# Pipeline(steps=[('clf', GradientBoostingClassifier(random_state=123))])
# Pipeline(steps=[('clf', LogisticRegression(random_state=123))])

# %%
print('----------------------------------------')
print('Accuracy')
print('----------------------------------------')
for index, val in enumerate(pipelines):
    print('%s : %.3f' % (pipeline_names[index], val.score(X_test_scaled, y_test)))
    
print('\n----------------------------------------')    
print('Weighted F1 Score')
print('----------------------------------------')
for index, val in enumerate(pipelines):
    print('%s : %.3f' % (pipeline_names[index],
                         f1_score(y_test, val.predict(X_test_scaled), average='weighted')))
# Out:
# ----------------------------------------
# Accuracy
# ----------------------------------------
# Decision Tree : 0.638
# Random Forest : 0.696
# Adaboost : 0.592
# Gradient Boosting : 0.630
# LogisticRegression : 0.557
#
# ----------------------------------------
# Weighted F1 Score
# ----------------------------------------
# Decision Tree : 0.641
# Random Forest : 0.690
# Adaboost : 0.561
# Gradient Boosting : 0.600
# LogisticRegression : 0.481

# %%
fig, ax = plt.subplots(3, 2, figsize=(14,13))
for index, val in enumerate(pipelines):
    plt.subplot(3,2,index+1)
    plot_cm(y_test, val.predict(X_test_scaled), pipeline_names[index], target_classes=2)
    
fig.tight_layout()
fig.delaxes(ax[-1,-1])
plt.show()

# %%
for index, val in enumerate(pipelines):
    print('----------------------------------------')
    print(pipeline_names[index])
    print('----------------------------------------')
    print(classification_report(y_test, val.predict(X_test)))
# Out:
# ----------------------------------------
# Decision Tree
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.50      0.14      0.22      2500
#            1       0.36      0.81      0.50      1719
#            2       0.00      0.00      0.00       347
#
#     accuracy                           0.38      4566
#    macro avg       0.29      0.32      0.24      4566
# weighted avg       0.41      0.38      0.31      4566
#
# ----------------------------------------
# Random Forest
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.58      0.51      0.54      2500
#            1       0.42      0.58      0.49      1719
#            2       0.00      0.00      0.00       347
#
#     accuracy                           0.50      4566
#    macro avg       0.33      0.36      0.34      4566
# weighted avg       0.48      0.50      0.48      4566
#
# ----------------------------------------
# Adaboost
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.56      0.90      0.69      2500
#            1       0.49      0.14      0.22      1719
#            2       0.00      0.00      0.00       347
#
#     accuracy                           0.55      4566
#    macro avg       0.35      0.35      0.30      4566
# weighted avg       0.49      0.55      0.46      4566
#
# ----------------------------------------
# Gradient Boosting
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53      2500
#            1       0.43      0.57      0.49      1719
#            2       0.04      0.01      0.02       347
#
#     accuracy                           0.49      4566
#    macro avg       0.35      0.36      0.35      4566
# weighted avg       0.48      0.49      0.48      4566
#
# ----------------------------------------
# LogisticRegression
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.25      0.37      2500
#            1       0.42      0.85      0.56      1719
#            2       0.05      0.02      0.03       347
#
#     accuracy                           0.46      4566
#    macro avg       0.38      0.37      0.32      4566
# weighted avg       0.52      0.46      0.41      4566

# %%
rf = pipelines[1].steps[0][1]
print(rf)

# Feature importances 
plt.figure(figsize=(12,8))
rf_feature_importance = plot_feature_importances(X_test, rf, 10)
# Out:
# RandomForestClassifier(random_state=123)
